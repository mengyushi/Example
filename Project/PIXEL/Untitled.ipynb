# %%
### PIXIL

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import skimage
from skimage import data
import math

# %%
im = plt.imread("test.jpg")

# %%
plt.imshow(im)

# %%
im.shape
# Out:
# (344, 382, 3)

# %%
# Seperate the image to 9*9

X = im.shape[0]
Y = im.shape[1]

piX = math.floor(X/20)
piY = math.floor(Y/20)

# %%
piX
# Out:
# 17

# %%
piY
# Out:
# 19

# %%
small = np.zeros((10,10,3))

# %%
plt.imshow(small)

# %%
small[0][0] = im[0][0]

# %%
plt.imshow(small)

# %%
for x in range(10):
    for y in range(10):
        small[x][y] = im[x*piX][y*piY]/256

# %%
plt.imshow(small)

# %%
def pixel_maker(filename,resolution):
    
    im = plt.imread(filename)
    X = im.shape[0]
    Y = im.shape[1]
    
    if resolution>X or resolution>Y:
        print("Resolution required larger than origin.")
        return 
    

    piX = resolution
    piY = math.floor((piX/X)*Y)
    
    sec = math.floor(X/piX)
    
    small = np.zeros((piX,piY,3))
    
    for x in range(piX):
        for y in range(piY):
            small[x][y] = im[x*sec][y*sec]/256
    plt.axis('off')
    plt.imshow(small)
    plt.savefig("PIXEL_"+filename)

# %%
pixel_maker("test.jpg",300)

# %%
pixel_maker("test1.jpg",10)

# %%
pixel_maker("test2.jpg",10)

# %%
pixel_maker("test3.jpg",10)

# %%
pixel_maker("de_parel.jpg",15)

# %%
pixel_maker("Creation_of_Adam.jpg",20)

# %%
pixel_maker("Mona_Lisa.jpg",15)

# %%
pixel_maker("Eiffel_Tower.jpg",5)

# %%
pixel_maker("red.jpeg",20)

# %%
pixel_maker("van_Gogh.jpg",30)

# %%
pixel_maker("ro.jpg",15)

# %%
pixel_maker("mengmeng.jpg",10)
