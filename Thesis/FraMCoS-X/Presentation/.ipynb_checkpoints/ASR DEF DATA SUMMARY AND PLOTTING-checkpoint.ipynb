# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
exp_df = pd.read_csv('Research_datas.csv')
sim_df = pd.read_csv('Simulation_datas.csv')

# %%
exp_df.head()
# Out:
#                       Resource Type  Expansion (%)  Control Expansion(%)  \
# 0  Giannini (2012), Mixture 1*  DEF          0.000                   0.0
# 1  Giannini (2012), Mixture 1*  DEF          0.102                   0.0
# 2  Giannini (2012), Mixture 1*  DEF          0.208                   0.0
# 3  Giannini (2012), Mixture 1*  DEF          0.344                   0.0
# 4  Giannini (2012), Mixture 1*  DEF          0.415                   0.0
#
#    Damaged Compressive Strength  Control Compressive Strength  \
# 0                     27.366667                     27.366667
# 1                     28.400000                     27.366667
# 2                     26.200000                     27.366667
# 3                     19.666667                     27.366667
# 4                     18.766667                     27.366667
#
#    Compressive Strength Loss  Damaged Elastic Modulus  \
# 0                   0.000000                23.133333
# 1                  -0.037759                20.033333
# 2                   0.042631                14.766667
# 3                   0.281364                 8.166667
# 4                   0.314251                 7.533333
#
#    Control Elastic Modulus  Elastic Modulus Loss Mean/Individual      Note  \
# 0                23.133333              0.000000            Mean  Cylinder
# 1                23.133333              0.134006            Mean  Cylinder
# 2                23.133333              0.361671            Mean  Cylinder
# 3                23.133333              0.646974            Mean  Cylinder
# 4                23.133333              0.674352            Mean  Cylinder
#
#    Unnamed: 12
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Compressive Strength Loss']>0.4].loc[exp_df['Expansion (%)']<0.5]
# Out:
#                        Resource Type  Expansion (%)  Control Expansion(%)  \
# 79  T.Ahmed et al.(2003) Mix B*  ASR          0.126                 0.093
# 80  T.Ahmed et al.(2003) Mix B*  ASR          0.156                 0.100
# 81  T.Ahmed et al.(2003) Mix B*  ASR          0.166                 0.113
# 82  T.Ahmed et al.(2003) Mix B*  ASR          0.170                 0.127
#
#     Damaged Compressive Strength  Control Compressive Strength  \
# 79                          27.5                         51.15
# 80                          26.2                         57.25
# 81                          26.4                         63.45
# 82                          26.5                         65.30
#
#     Compressive Strength Loss  Damaged Elastic Modulus  \
# 79                   0.462366                     2.93
# 80                   0.542358                     2.89
# 81                   0.583924                     2.17
# 82                   0.594181                     1.72
#
#     Control Elastic Modulus  Elastic Modulus Loss Mean/Individual Note  \
# 79                    33.70              0.913056             NaN  NaN
# 80                    33.95              0.914875             NaN  NaN
# 81                    35.25              0.938440             NaN  NaN
# 82                    36.36              0.952695             NaN  NaN
#
#     Unnamed: 12
# 79          NaN
# 80          NaN
# 81          NaN
# 82          NaN

# %%
exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Elastic Modulus Loss']>0.6].loc[exp_df['Expansion (%)']<0.25]
# Out:
#                        Resource Type  Expansion (%)  Control Expansion(%)  \
# 78  T.Ahmed et al.(2003) Mix B*  ASR          0.020                 0.060
# 79  T.Ahmed et al.(2003) Mix B*  ASR          0.126                 0.093
# 80  T.Ahmed et al.(2003) Mix B*  ASR          0.156                 0.100
# 81  T.Ahmed et al.(2003) Mix B*  ASR          0.166                 0.113
# 82  T.Ahmed et al.(2003) Mix B*  ASR          0.170                 0.127
#
#     Damaged Compressive Strength  Control Compressive Strength  \
# 78                          38.1                         51.15
# 79                          27.5                         51.15
# 80                          26.2                         57.25
# 81                          26.4                         63.45
# 82                          26.5                         65.30
#
#     Compressive Strength Loss  Damaged Elastic Modulus  \
# 78                   0.255132                     8.85
# 79                   0.462366                     2.93
# 80                   0.542358                     2.89
# 81                   0.583924                     2.17
# 82                   0.594181                     1.72
#
#     Control Elastic Modulus  Elastic Modulus Loss Mean/Individual Note  \
# 78                    32.45              0.727273             NaN  NaN
# 79                    33.70              0.913056             NaN  NaN
# 80                    33.95              0.914875             NaN  NaN
# 81                    35.25              0.938440             NaN  NaN
# 82                    36.36              0.952695             NaN  NaN
#
#     Unnamed: 12
# 78          NaN
# 79          NaN
# 80          NaN
# 81          NaN
# 82          NaN

# %%
exp_df = exp_df.loc[exp_df['Resource']!='T.Ahmed et al.(2003) Mix B*']

# %% [markdown]
# T.Ahmed et al.(2003) Mix B*
#
# Swamy & Al-Asali (1988) 4 Mix 4.5% (From ALKAN...
#
# Swamy & Al-Asali (1988) 4 Mix 15% (From ALKAN ...

# %%
print("======== ASR ========")
print("ASR COMPRESSIVE STRENGTH: ",exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Damaged Compressive Strength']>0].shape[0])
print("ASR ELASTIC MODULUS: ",exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Damaged Elastic Modulus']>0].shape[0])
print("======== DEF ========")
print("DEF COMPRESSIVE STRENGTH: ",exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Damaged Compressive Strength']>0].shape[0])
print("DEF ELASTIC MODULUS: ",exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Damaged Elastic Modulus']>0].shape[0])
# Out:
# ======== ASR ========
# ASR COMPRESSIVE STRENGTH:  44
# ASR ELASTIC MODULUS:  49
# ======== DEF ========
# DEF COMPRESSIVE STRENGTH:  31
# DEF ELASTIC MODULUS:  41

# %%
exp_df.loc[exp_df['Type']=='ASR'].plot(kind='scatter',x='Expansion (%)',y='Compressive Strength Loss',color='red')
#exp_df.loc[exp_df['Type']=='DEF'].plot(kind='scatter',x='Expansion (%)',y='Compressive Strength Loss',color='blue')

#exp_df.loc[exp_df['Type']=='ASR'].plot(kind='scatter',x='Expansion (%)',y='Elastic Modulus Loss',color='red')
#exp_df.loc[exp_df['Type']=='DEF'].plot(kind='scatter',x='Expansion (%)',y='Elastic Modulus Loss',color='red')

#plt.show()

# %%
exp_ASR_exp = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Compressive Strength Loss']>0]['Expansion (%)'].tolist()
exp_ASR_CS = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Compressive Strength Loss']>0]['Compressive Strength Loss'].tolist()
exp_ASR_EM = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Compressive Strength Loss']>0]['Elastic Modulus Loss'].tolist()
exp_ASR_LABELS = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Compressive Strength Loss']>0]['Resource'].tolist()

exp_DEF_exp = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Compressive Strength Loss']>0]['Expansion (%)'].tolist()
exp_DEF_CS = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Compressive Strength Loss']>0]['Compressive Strength Loss'].tolist()
exp_DEF_EM = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Compressive Strength Loss']>0]['Elastic Modulus Loss'].tolist()
exp_DEF_LABELS = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Compressive Strength Loss']>0]['Resource'].tolist()

# %%
sim_ASR_exp = sim_df.loc[sim_df['Type']=='ASR']['Expansion (%)'].tolist()
sim_ASR_CS = sim_df.loc[sim_df['Type']=='ASR']['Compressive Strength Loss'].tolist()
sim_ASR_EM = sim_df.loc[sim_df['Type']=='ASR']['Elastic Modulus Loss'].tolist()
sim_ASR_LABELS = sim_df.loc[sim_df['Type']=='ASR']['Resource'].tolist()

sim_DEF_exp = sim_df.loc[sim_df['Type']=='DEF']['Expansion (%)'].tolist()
sim_DEF_CS = sim_df.loc[sim_df['Type']=='DEF']['Compressive Strength Loss'].tolist()
sim_DEF_EM = sim_df.loc[sim_df['Type']=='DEF']['Elastic Modulus Loss'].tolist()
sim_DEF_LABELS = sim_df.loc[sim_df['Type']=='DEF']['Resource'].tolist()

# %%
plt.clf()

fig,axes = plt.subplots(2,2,sharey=True,sharex=True,figsize=(15, 10))

ax1 = axes[0, 0]

ax1.plot(exp_ASR_exp,exp_ASR_CS,'ro',mfc='none',label = "ASR Compressive Strength Loss - Experimental")
ax1.plot(sim_ASR_exp,sim_ASR_CS,'ko',label = "ASR Compressive Strength Loss - Simulated")

#ax1.plot(0.3010,(28.098-21.345)/28.098,'bo',label = "ASR Compressive Strength Loss - Simulated(ASR Gel)")
#ax1.plot(0.6411,(28.098-18.139)/28.098,'bo')



ax1.set_xlabel("Expansion(%)")
ax1.set_ylabel("Loss")
ax1.set_title("ASR Compressive Strength Loss")
ax1.legend(loc = 4)

ax1.set_xlim([0, 3])
ax1.set_ylim([0, 1])

ax2 = axes[0, 1]

ax2.plot(exp_ASR_exp,exp_ASR_EM, 'ro', mfc='none',label = "ASR Elastic Modulus Loss - Experimental")
ax2.plot(sim_ASR_exp,sim_ASR_EM, 'ko',label = "ASR Elastic Modulus Loss - Simulated")

ax2.set_xlabel("Expansion(%)")
ax2.set_ylabel("Loss")
ax2.set_title("ASR Elastic Modulus Loss")
ax2.legend(loc = 4)

ax3 = axes[1, 0]

ax3.plot(exp_DEF_exp,exp_DEF_CS,'bo', mfc='none',label = "DEF Compressive Strength Loss - Experimental")
ax3.plot(sim_DEF_exp,sim_DEF_CS,'ko',label = "DEF Compressive Strength Loss - Simulated")

ax3.set_xlabel("Expansion(%)")
ax3.set_ylabel("Loss")
ax3.set_title("DEF Compressive Strength Loss")
ax3.legend(loc = 4)

ax4 = axes[1, 1]

ax4.plot(exp_DEF_exp,exp_DEF_EM, 'bo', mfc='none',label = "DEF Elastic Modulus Loss - Experimental")
ax4.plot(sim_DEF_exp,sim_DEF_EM, 'ko',label = "ASR Elastic Modulus Loss - Experimental")

ax4.set_xlabel("Expansion(%)")
ax4.set_ylabel("Loss")
ax4.set_title("DEF Elastic Modulus Loss")
ax4.legend(loc = 4)

plt.show()

# %%
from __future__ import absolute_import, division, print_function
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from keras import models
from keras import layers
from keras import optimizers
from keras.wrappers import scikit_learn


from sklearn.preprocessing import PolynomialFeatures  
from sklearn.linear_model import LinearRegression

from sklearn.externals import joblib

import pickle

from keras.models import load_model

seed = 1
np.random.seed(seed)
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_x = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Damaged Compressive Strength']>0]['Expansion (%)'].as_matrix()
train_y = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Damaged Compressive Strength']>0]['Compressive Strength Loss'].as_matrix()
train_x = train_x.reshape(train_x.shape[0],1)

# %%
poly_features = PolynomialFeatures(degree = 5)  
train_data_poly = poly_features.fit_transform(train_x)
#test_data_poly = poly_features.fit_transform(test_x)
ASR_CS_regr = LinearRegression()
ASR_CS_regr.fit(train_data_poly, train_y)
train_y_pred = ASR_CS_regr.predict(train_data_poly)
#print('Coefficients: \n', regr.coef_)

plt.scatter(train_y, train_y_pred)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.xlim(plt.xlim())
plt.ylim(plt.ylim())
_ = plt.plot([-1, 1], [-1, 1],'r--')
    
print("")
print('Mean Abs Error: ',abs((train_y_pred-train_y)/len(train_y)).sum())
# Out:
# Mean Abs Error:  0.07392176307542847

# %%
train_x = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Damaged Compressive Strength']>0]['Expansion (%)'].as_matrix()
train_y = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Damaged Compressive Strength']>0]['Compressive Strength Loss'].as_matrix()
train_x = train_x.reshape(train_x.shape[0],1)

# %%
poly_features = PolynomialFeatures(degree = 5)  
train_data_poly = poly_features.fit_transform(train_x)
#test_data_poly = poly_features.fit_transform(test_x)
DEF_CS_regr = LinearRegression()
DEF_CS_regr.fit(train_data_poly, train_y)
train_y_pred = DEF_CS_regr.predict(train_data_poly)
#print('Coefficients: \n', regr.coef_)

plt.scatter(train_y, train_y_pred)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.xlim(plt.xlim())
plt.ylim(plt.ylim())
_ = plt.plot([-1, 1], [-1, 1],'r--')
    
print("")
print('Mean Abs Error: ',abs((train_y_pred-train_y)/len(train_y)).sum())
# Out:
# Mean Abs Error:  0.05252598925619444

# %%
train_x = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Damaged Elastic Modulus']>0]['Expansion (%)'].as_matrix()
train_y = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Damaged Elastic Modulus']>0]['Elastic Modulus Loss'].as_matrix()
train_x = train_x.reshape(train_x.shape[0],1)

# %%
poly_features = PolynomialFeatures(degree = 5)  
train_data_poly = poly_features.fit_transform(train_x)
#test_data_poly = poly_features.fit_transform(test_x)
ASR_EM_regr = LinearRegression()
ASR_EM_regr.fit(train_data_poly, train_y)
train_y_pred = ASR_EM_regr.predict(train_data_poly)
#print('Coefficients: \n', regr.coef_)

plt.scatter(train_y, train_y_pred)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.xlim(plt.xlim())
plt.ylim(plt.ylim())
_ = plt.plot([-1, 1], [-1, 1],'r--')
    
print("")
print('Mean Abs Error: ',abs((train_y_pred-train_y)/len(train_y)).sum())
# Out:
# Mean Abs Error:  0.06866488608343589

# %%
train_x = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Damaged Elastic Modulus']>0]['Expansion (%)'].as_matrix()
train_y = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Damaged Elastic Modulus']>0]['Elastic Modulus Loss'].as_matrix()
train_x = train_x.reshape(train_x.shape[0],1)

# %%
poly_features = PolynomialFeatures(degree = 5)  
train_data_poly = poly_features.fit_transform(train_x)
#test_data_poly = poly_features.fit_transform(test_x)
DEF_EM_regr = LinearRegression()
DEF_EM_regr.fit(train_data_poly, train_y)
train_y_pred = DEF_EM_regr.predict(train_data_poly)
#print('Coefficients: \n', regr.coef_)

plt.scatter(train_y, train_y_pred)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.xlim(plt.xlim())
plt.ylim(plt.ylim())
_ = plt.plot([-1, 1], [-1, 1],'r--')
    
print("")
print('Mean Abs Error: ',abs((train_y_pred-train_y)/len(train_y)).sum())
# Out:
# Mean Abs Error:  0.08282942614935415

# %%
def single_pred(regr_model,poly_features, exp):
    try:
        x = np.array([exp]).reshape(1, -1)
        x_poly = poly_features.fit_transform(x)
        train_y_pred = regr_model.predict(x_poly)
        return train_y_pred[0]
    except:
        return 'NaN'

# %%
single_pred(ASR_EM_regr,poly_features, 0.4)
# Out:
# 0.5044890702000923

# %%
plt.clf()

fig,axes = plt.subplots(2,2,sharey=True,sharex=True,figsize=(15, 10))

ax1 = axes[0, 0]

ax1.plot(exp_ASR_exp,exp_ASR_CS,'ro',mfc='none',label = "ASR Compressive Strength Loss - Experimental")
#ax1.plot(sim_ASR_exp,sim_ASR_CS,'ko',label = "ASR Compressive Strength Loss - Simulated")

#ax1.plot(0.3010,(28.098-21.345)/28.098,'bo',label = "ASR Compressive Strength Loss - Simulated(ASR Gel)")
#ax1.plot(0.6411,(28.098-18.139)/28.098,'bo')


ax1.set_xlabel("Expansion(%)")
ax1.set_ylabel("Loss")
ax1.set_title("ASR Compressive Strength Loss")
ax1.legend(loc = 4)

ax1.set_xlim([0, 2])
ax1.set_ylim([0, 1])

ax2 = axes[0, 1]

ax2.plot(exp_ASR_exp,exp_ASR_EM, 'ro', mfc='none',label = "ASR Elastic Modulus Loss - Experimental")
#ax2.plot(sim_ASR_exp,sim_ASR_EM, 'ko',label = "ASR Elastic Modulus Loss - Simulated")

ax2.set_xlabel("Expansion(%)")
ax2.set_ylabel("Loss")
ax2.set_title("ASR Elastic Modulus Loss")
ax2.legend(loc = 4)

ax3 = axes[1, 0]

ax3.plot(exp_DEF_exp,exp_DEF_CS,'bo', mfc='none',label = "DEF Compressive Strength Loss - Experimental")
#ax3.plot(sim_DEF_exp,sim_DEF_CS,'ko',label = "DEF Compressive Strength Loss - Simulated")

ax3.set_xlabel("Expansion(%)")
ax3.set_ylabel("Loss")
ax3.set_title("DEF Compressive Strength Loss")
ax3.legend(loc = 4)

ax4 = axes[1, 1]

ax4.plot(exp_DEF_exp,exp_DEF_EM, 'bo', mfc='none',label = "DEF Elastic Modulus Loss - Experimental")
#ax4.plot(sim_DEF_exp,sim_DEF_EM, 'ko',label = "ASR Elastic Modulus Loss - Experimental")

ax4.set_xlabel("Expansion(%)")
ax4.set_ylabel("Loss")
ax4.set_title("DEF Elastic Modulus Loss")
ax4.legend(loc = 4)

plt.show()

# %%
exp_df
# Out:
#                                               Resource Type  Expansion (%)  \
# 0                          Giannini (2012), Mixture 1*  DEF       0.000000
# 1                          Giannini (2012), Mixture 1*  DEF       0.102000
# 2                          Giannini (2012), Mixture 1*  DEF       0.208000
# 3                          Giannini (2012), Mixture 1*  DEF       0.344000
# 4                          Giannini (2012), Mixture 1*  DEF       0.415000
# 5                          Giannini (2012), Mixture 1*  DEF       0.506000
# 6                          Giannini (2012), Mixture 1*  DEF       1.011000
# 7                          Giannini (2012), Mixture 2*  DEF       0.008000
# 8                          Giannini (2012), Mixture 2*  DEF       0.079000
# 9                          Giannini (2012), Mixture 2*  DEF       0.179000
# 10                         Giannini (2012), Mixture 2*  DEF       0.266000
# 11                         Giannini (2012), Mixture 2*  DEF       0.327000
# 12                         Giannini (2012), Mixture 2*  DEF       0.454000
# 13                         Giannini (2012), Mixture 1*  ASR       0.009000
# 14                         Giannini (2012), Mixture 1*  ASR       0.109000
# 15                         Giannini (2012), Mixture 1*  ASR       0.181000
# 16                         Giannini (2012), Mixture 1*  ASR       0.272000
# 17                         Giannini (2012), Mixture 1*  ASR       0.379000
# 18                         Giannini (2012), Mixture 1*  ASR       0.416000
# 19                         Giannini (2012), Mixture 1*  ASR       0.429000
# 20                         Giannini (2012), Mixture 2*  ASR       0.010000
# 21                         Giannini (2012), Mixture 2*  ASR       0.045000
# 22                         Giannini (2012), Mixture 2*  ASR       0.074000
# 23                         Giannini (2012), Mixture 2*  ASR       0.135000
# 24                         Giannini (2012), Mixture 2*  ASR       0.160000
# 25                         Giannini (2012), Mixture 2*  ASR       0.177000
# 26                             Brunetaud et al. (2008)  DEF       0.000000
# 27                             Brunetaud et al. (2008)  DEF       0.477632
# 28                             Brunetaud et al. (2008)  DEF       0.540789
# 29                             Brunetaud et al. (2008)  DEF       0.538158
# ..                                                 ...  ...            ...
# 101  Swamy & Al-Asali (1988) 2 Mix 15% (From ALKAN ...  ASR       0.200000
# 102  Swamy & Al-Asali (1988) 2 Mix 15% (From ALKAN ...  ASR       0.400000
# 103  Swamy & Al-Asali (1988) 2 Mix 15% (From ALKAN ...  ASR       0.600000
# 104  Swamy & Al-Asali (1988) 3 Mix 4.5% (From ALKAN...  ASR       0.004000
# 105  Swamy & Al-Asali (1988) 3 Mix 4.5% (From ALKAN...  ASR       0.071000
# 106  Swamy & Al-Asali (1988) 3 Mix 4.5% (From ALKAN...  ASR       0.097000
# 107  Swamy & Al-Asali (1988) 3 Mix 4.5% (From ALKAN...  ASR       0.316000
# 108  Swamy & Al-Asali (1988) 3 Mix 4.5% (From ALKAN...  ASR       0.883000
# 109  Swamy & Al-Asali (1988) 3 Mix 4.5% (From ALKAN...  ASR       1.644000
# 110  Swamy & Al-Asali (1988) 3 Mix 15% (From ALKAN ...  ASR       0.005000
# 111  Swamy & Al-Asali (1988) 3 Mix 15% (From ALKAN ...  ASR       0.023000
# 112  Swamy & Al-Asali (1988) 3 Mix 15% (From ALKAN ...  ASR       0.259000
# 113  Swamy & Al-Asali (1988) 3 Mix 15% (From ALKAN ...  ASR       0.623000
# 114  Swamy & Al-Asali (1988) 4 Mix 4.5% (From ALKAN...  ASR       0.000000
# 115  Swamy & Al-Asali (1988) 4 Mix 4.5% (From ALKAN...  ASR       0.071000
# 116  Swamy & Al-Asali (1988) 4 Mix 4.5% (From ALKAN...  ASR       0.097000
# 117  Swamy & Al-Asali (1988) 4 Mix 4.5% (From ALKAN...  ASR       0.316000
# 118  Swamy & Al-Asali (1988) 4 Mix 4.5% (From ALKAN...  ASR       0.883000
# 119  Swamy & Al-Asali (1988) 4 Mix 4.5% (From ALKAN...  ASR       1.442000
# 120  Swamy & Al-Asali (1988) 4 Mix 4.5% (From ALKAN...  ASR       1.618000
# 121  Swamy & Al-Asali (1988) 4 Mix 4.5% (From ALKAN...  ASR       1.644000
# 122  Swamy & Al-Asali (1988) 4 Mix 15% (From ALKAN ...  ASR       0.000000
# 123  Swamy & Al-Asali (1988) 4 Mix 15% (From ALKAN ...  ASR       0.000000
# 124  Swamy & Al-Asali (1988) 4 Mix 15% (From ALKAN ...  ASR       0.005000
# 125  Swamy & Al-Asali (1988) 4 Mix 15% (From ALKAN ...  ASR       0.023000
# 126  Swamy & Al-Asali (1988) 4 Mix 15% (From ALKAN ...  ASR       0.259000
# 127  Swamy & Al-Asali (1988) 4 Mix 15% (From ALKAN ...  ASR       0.615000
# 128  Swamy & Al-Asali (1988) 4 Mix 15% (From ALKAN ...  ASR       0.625000
# 129  Swamy & Al-Asali (1988) 4 Mix 15% (From ALKAN ...  ASR       0.623000
# 130                                        小川森平(2018)*  ASR       2.332000
#
#      Control Expansion(%)  Damaged Compressive Strength  \
# 0                   0.000                     27.366667
# 1                   0.000                     28.400000
# 2                   0.000                     26.200000
# 3                   0.000                     19.666667
# 4                   0.000                     18.766667
# 5                   0.000                     18.333333
# 6                   0.000                     15.933333
# 7                   0.008                     33.000000
# 8                   0.008                     32.900000
# 9                   0.008                     32.433333
# 10                  0.008                     29.333333
# 11                  0.008                     32.900000
# 12                  0.008                     25.133333
# 13                  0.009                     33.900000
# 14                  0.009                     35.366667
# 15                  0.009                     33.266667
# 16                  0.009                     30.533333
# 17                  0.009                     28.900000
# 18                  0.009                     29.366667
# 19                  0.009                     29.900000
# 20                  0.010                     35.866667
# 21                  0.010                     36.633333
# 22                  0.010                     37.966667
# 23                  0.010                     39.700000
# 24                  0.010                     41.566667
# 25                  0.010                     42.033333
# 26                  0.000                     41.310000
# 27                  0.000                     34.332220
# 28                  0.000                     34.031720
# 29                  0.000                     30.876461
# ..                    ...                           ...
# 101                 0.000                      0.850000
# 102                 0.000                      0.700000
# 103                 0.000                      0.600000
# 104                 0.000                           NaN
# 105                 0.000                           NaN
# 106                 0.001                           NaN
# 107                 0.003                           NaN
# 108                 0.017                           NaN
# 109                 0.021                           NaN
# 110                 0.001                           NaN
# 111                 0.003                           NaN
# 112                 0.017                           NaN
# 113                 0.021                           NaN
# 114                 0.000                           NaN
# 115                 0.000                           NaN
# 116                 0.000                           NaN
# 117                 0.000                           NaN
# 118                 0.000                           NaN
# 119                 0.000                           NaN
# 120                 0.000                           NaN
# 121                 0.000                           NaN
# 122                 0.000                           NaN
# 123                 0.000                           NaN
# 124                 0.000                           NaN
# 125                 0.000                           NaN
# 126                 0.000                           NaN
# 127                 0.000                           NaN
# 128                 0.000                           NaN
# 129                 0.000                           NaN
# 130                 0.320                     13.800000
#
#      Control Compressive Strength  Compressive Strength Loss  \
# 0                       27.366667                   0.000000
# 1                       27.366667                  -0.037759
# 2                       27.366667                   0.042631
# 3                       27.366667                   0.281364
# 4                       27.366667                   0.314251
# 5                       27.366667                   0.330085
# 6                       27.366667                   0.417783
# 7                       33.000000                   0.000000
# 8                       33.000000                   0.003030
# 9                       33.000000                   0.017172
# 10                      33.000000                   0.111111
# 11                      33.000000                   0.003030
# 12                      33.000000                   0.238384
# 13                      33.900000                   0.000000
# 14                      33.900000                  -0.043265
# 15                      33.900000                   0.018682
# 16                      33.900000                   0.099312
# 17                      33.900000                   0.147493
# 18                      33.900000                   0.133727
# 19                      33.900000                   0.117994
# 20                      35.866667                   0.000000
# 21                      35.866667                  -0.021375
# 22                      35.866667                  -0.058550
# 23                      35.866667                  -0.106877
# 24                      35.866667                  -0.158922
# 25                      35.866667                  -0.171933
# 26                      41.310000                   0.000000
# 27                      41.310000                   0.168913
# 28                      41.310000                   0.176187
# 29                      41.310000                   0.252567
# ..                            ...                        ...
# 101                      1.000000                   0.150000
# 102                      1.000000                   0.300000
# 103                      1.000000                   0.400000
# 104                           NaN                        NaN
# 105                           NaN                        NaN
# 106                           NaN                        NaN
# 107                           NaN                        NaN
# 108                           NaN                        NaN
# 109                           NaN                        NaN
# 110                           NaN                        NaN
# 111                           NaN                        NaN
# 112                           NaN                        NaN
# 113                           NaN                        NaN
# 114                           NaN                        NaN
# 115                           NaN                        NaN
# 116                           NaN                        NaN
# 117                           NaN                        NaN
# 118                           NaN                        NaN
# 119                           NaN                        NaN
# 120                           NaN                        NaN
# 121                           NaN                        NaN
# 122                           NaN                        NaN
# 123                           NaN                        NaN
# 124                           NaN                        NaN
# 125                           NaN                        NaN
# 126                           NaN                        NaN
# 127                           NaN                        NaN
# 128                           NaN                        NaN
# 129                           NaN                        NaN
# 130                     24.000000                   0.425000
#
#      Damaged Elastic Modulus  Control Elastic Modulus  Elastic Modulus Loss  \
# 0                  23.133333                23.133333              0.000000
# 1                  20.033333                23.133333              0.134006
# 2                  14.766667                23.133333              0.361671
# 3                   8.166667                23.133333              0.646974
# 4                   7.533333                23.133333              0.674352
# 5                   6.700000                23.133333              0.710375
# 6                   5.833333                23.133333              0.747839
# 7                  23.566667                23.566667              0.000000
# 8                  20.133333                23.566667              0.145686
# 9                  17.933333                23.566667              0.239038
# 10                 16.200000                23.566667              0.312588
# 11                 18.600000                23.566667              0.210750
# 12                  9.600000                23.566667              0.592645
# 13                 29.100000                29.100000              0.000000
# 14                 20.066667                29.100000              0.310424
# 15                 17.833333                29.100000              0.387171
# 16                 14.866667                29.100000              0.489118
# 17                 13.066667                29.100000              0.550974
# 18                 15.966667                29.100000              0.451317
# 19                 17.050000                29.100000              0.414089
# 20                 29.500000                29.500000              0.000000
# 21                 25.700000                29.500000              0.128814
# 22                 24.600000                29.500000              0.166102
# 23                 23.933333                29.500000              0.188701
# 24                 22.633333                29.500000              0.232768
# 25                 23.933333                29.500000              0.188701
# 26                       NaN                      NaN                   NaN
# 27                       NaN                      NaN                   NaN
# 28                       NaN                      NaN                   NaN
# 29                       NaN                      NaN                   NaN
# ..                       ...                      ...                   ...
# 101                      NaN                      NaN                   NaN
# 102                      NaN                      NaN                   NaN
# 103                      NaN                      NaN                   NaN
# 104                37.500000                38.800000              0.033505
# 105                32.700000                41.000000              0.202439
# 106                23.700000                41.100000              0.423358
# 107                20.800000                42.500000              0.510588
# 108                19.600000                44.200000              0.556561
# 109                10.400000                45.500000              0.771429
# 110                40.200000                41.100000              0.021898
# 111                40.800000                42.500000              0.040000
# 112                24.000000                44.200000              0.457014
# 113                18.900000                45.500000              0.584615
# 114                 0.954000                 1.000000              0.046000
# 115                 0.797000                 1.000000              0.203000
# 116                 0.577000                 1.000000              0.423000
# 117                 0.489000                 1.000000              0.511000
# 118                 0.442000                 1.000000              0.558000
# 119                 0.253000                 1.000000              0.747000
# 120                 0.181000                 1.000000              0.819000
# 121                 0.229000                 1.000000              0.771000
# 122                 0.973000                 1.000000              0.027000
# 123                 0.962000                 1.000000              0.038000
# 124                 0.977000                 1.000000              0.023000
# 125                 0.960000                 1.000000              0.040000
# 126                 0.543000                 1.000000              0.457000
# 127                 0.320000                 1.000000              0.680000
# 128                 0.402000                 1.000000              0.598000
# 129                 0.416000                 1.000000              0.584000
# 130                13.680000                24.000000              0.430000
#
#     Mean/Individual           Note  Unnamed: 12
# 0              Mean       Cylinder          NaN
# 1              Mean       Cylinder          NaN
# 2              Mean       Cylinder          NaN
# 3              Mean       Cylinder          NaN
# 4              Mean       Cylinder          NaN
# 5              Mean       Cylinder          NaN
# 6              Mean       Cylinder          NaN
# 7              Mean       Cylinder          NaN
# 8              Mean       Cylinder          NaN
# 9              Mean       Cylinder          NaN
# 10             Mean       Cylinder          NaN
# 11             Mean       Cylinder          NaN
# 12             Mean       Cylinder          NaN
# 13             Mean       Cylinder          NaN
# 14             Mean       Cylinder          NaN
# 15             Mean       Cylinder          NaN
# 16             Mean       Cylinder          NaN
# 17             Mean       Cylinder          NaN
# 18             Mean       Cylinder          NaN
# 19             Mean       Cylinder          NaN
# 20             Mean       Cylinder          NaN
# 21             Mean       Cylinder          NaN
# 22             Mean       Cylinder          NaN
# 23             Mean       Cylinder          NaN
# 24             Mean       Cylinder          NaN
# 25             Mean       Cylinder          NaN
# 26              NaN            NaN          NaN
# 27              NaN            NaN          NaN
# 28              NaN            NaN          NaN
# 29              NaN            NaN          NaN
# ..              ...            ...          ...
# 101             NaN  In Loss Ratio          NaN
# 102             NaN  In Loss Ratio          NaN
# 103             NaN  In Loss Ratio          NaN
# 104             NaN            NaN          NaN
# 105             NaN            NaN          NaN
# 106             NaN            NaN          NaN
# 107             NaN            NaN          NaN
# 108             NaN            NaN          NaN
# 109             NaN            NaN          NaN
# 110             NaN            NaN          NaN
# 111             NaN            NaN          NaN
# 112             NaN            NaN          NaN
# 113             NaN            NaN          NaN
# 114             NaN            NaN          NaN
# 115             NaN            NaN          NaN
# 116             NaN            NaN          NaN
# 117             NaN            NaN          NaN
# 118             NaN            NaN          NaN
# 119             NaN            NaN          NaN
# 120             NaN            NaN          NaN
# 121             NaN            NaN          NaN
# 122             NaN            NaN          NaN
# 123             NaN            NaN          NaN
# 124             NaN            NaN          NaN
# 125             NaN            NaN          NaN
# 126             NaN            NaN          NaN
# 127             NaN            NaN          NaN
# 128             NaN            NaN          NaN
# 129             NaN            NaN          NaN
# 130             NaN       Cylinder          NaN
#
# [126 rows x 13 columns]

# %%
fig, ax = plt.subplots(figsize=(10,8))

plt.plot(exp_ASR_exp,exp_ASR_CS,'ro',mfc='none',label = "ASR Compressive Strength Loss - Experimental")
plt.plot(sim_ASR_exp,sim_ASR_CS,'ko',label = "A15% ASR Compressive Strength")

#ax1.plot(0.3010,(28.098-21.345)/28.098,'bo',label = "ASR Compressive Strength Loss - Simulated(ASR Gel)")
#ax1.plot(0.6411,(28.098-18.139)/28.098,'bo')

plt.plot(0.004089*100,1-27.348/34.115,'bo', label = 'A30% ASR Compressive Strength')
plt.plot(0.008697*100,1-23.018/34.115,'bo')


plt.xlabel("Expansion(%)",fontsize = 'xx-large')
plt.ylabel("Loss",fontsize = 'xx-large')
plt.legend(fontsize = 'xx-large')
plt.title("ASR Compressive Strength",fontsize = 'xx-large')
# Out:
# Text(0.5,1,'ASR Compressive Strength')

# %%
exp_ASR_CS_Remained = []
for i in range(len(exp_ASR_CS)):
    exp_ASR_CS_Remained.append(1-exp_ASR_CS[i])


fig, ax = plt.subplots(figsize=(8,5))

plt.plot(exp_ASR_exp,exp_ASR_CS_Remained,'ro')

plt.xticks([0,1.0,2.0],fontsize = 'xx-large')
plt.yticks([0,0.5,1],fontsize = 'xx-large')


plt.xlabel("Expansion(%)",fontsize = 'xx-large')
plt.ylabel("Residual Compression Strength",fontsize = 'xx-large')
# Out:
# Text(0,0.5,'Residual Compression Strength')

# %%
exp_DEF_CS_Remained = []
for i in range(len(exp_DEF_CS)):
    exp_DEF_CS_Remained.append(1-exp_DEF_CS[i])


fig, ax = plt.subplots(figsize=(8,5))

plt.plot(exp_DEF_exp,exp_DEF_CS_Remained,'bo')

plt.xticks([0,1.0,2.0],fontsize = 'xx-large')
plt.yticks([0,0.5,1],fontsize = 'xx-large')


plt.xlabel("Expansion(%)",fontsize = 'xx-large')
plt.ylabel("Residual Compression Strength",fontsize = 'xx-large')
# Out:
# Text(0,0.5,'Residual Compression Strength')
