# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
exp_df = pd.read_excel('Research_Result_v2.xlsx')

exp_df = exp_df.loc[exp_df['Use']==1]

exp_ASR_exp = exp_df.loc[exp_df['Type']=='ASR']['Expansion (%)'].tolist()
exp_ASR_CS = exp_df.loc[exp_df['Type']=='ASR']['Compressive Strength Remained'].tolist()
exp_ASR_EM = exp_df.loc[exp_df['Type']=='ASR']['Elastic Modulus Remained'].tolist()
exp_ASR_LABELS = exp_df.loc[exp_df['Type']=='ASR']['Resource'].tolist()

exp_DEF_exp = exp_df.loc[exp_df['Type']=='DEF']['Expansion (%)'].tolist()
exp_DEF_CS = exp_df.loc[exp_df['Type']=='DEF']['Compressive Strength Remained'].tolist()
exp_DEF_EM = exp_df.loc[exp_df['Type']=='DEF']['Elastic Modulus Remained'].tolist()
exp_DEF_LABELS = exp_df.loc[exp_df['Type']=='DEF']['Resource'].tolist()

##############################################################

ASR_exp_GIANNINI1 = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='Giannini (2012), Mixture 1*']['Expansion (%)'].tolist()
ASR_CS_GIANNINI1 = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='Giannini (2012), Mixture 1*']['Compressive Strength Remained'].tolist()
ASR_EM_GIANNINI1 = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='Giannini (2012), Mixture 1*']['Elastic Modulus Remained'].tolist()

ASR_exp_ALKAN = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='ALKAN HAFCI (2013)*']['Expansion (%)'].tolist()
ASR_CS_ALKAN = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='ALKAN HAFCI (2013)*']['Compressive Strength Remained'].tolist()
ASR_EM_ALKAN = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='ALKAN HAFCI (2013)*']['Elastic Modulus Remained'].tolist()

ASR_exp_TAHMED = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='T.Ahmed et al.(2003) Mix B*']['Expansion (%)'].tolist()
ASR_CS_TAHMED = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='T.Ahmed et al.(2003) Mix B*']['Compressive Strength Remained'].tolist()
ASR_EM_TAHMED = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='T.Ahmed et al.(2003) Mix B*']['Elastic Modulus Remained'].tolist()

ASR_exp_SWAMY = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='Swamy & Al-Asali (1988)']['Expansion (%)'].tolist()
ASR_CS_SWAMY = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='Swamy & Al-Asali (1988)']['Compressive Strength Remained'].tolist()
ASR_EM_SWAMY = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='Swamy & Al-Asali (1988)']['Elastic Modulus Remained'].tolist()

DEF_exp_GIANNINI1 = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='Giannini (2012), Mixture 1*']['Expansion (%)'].tolist()
DEF_CS_GIANNINI1 = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='Giannini (2012), Mixture 1*']['Compressive Strength Remained'].tolist()
DEF_EM_GIANNINI1 = exp_df.loc[exp_df['Type']=='ASR'].loc[exp_df['Resource']=='Giannini (2012), Mixture 1*']['Elastic Modulus Remained'].tolist()

DEF_exp_GIANNINI2 = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Resource']=='Giannini (2012), Mixture 2*']['Expansion (%)'].tolist()
DEF_CS_GIANNINI2 = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Resource']=='Giannini (2012), Mixture 2*']['Compressive Strength Remained'].tolist()
DEF_EM_GIANNINI2 = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Resource']=='Giannini (2012), Mixture 2*']['Elastic Modulus Remained'].tolist()

DEF_exp_BRUNETAUD = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Resource']=='Brunetaud et al. (2008)']['Expansion (%)'].tolist()
DEF_CS_BRUNETAUD = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Resource']=='Brunetaud et al. (2008)']['Compressive Strength Remained'].tolist()

DEF_exp_BOUZABATA = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Resource']=='Bouzabata et al. (2012)']['Expansion (%)'].tolist()
DEF_EM_BOUZABATA = exp_df.loc[exp_df['Type']=='DEF'].loc[exp_df['Resource']=='Bouzabata et al. (2012)']['Elastic Modulus Remained'].tolist()

# %%
ASR_EM_TAHMED
# Out:
# [0.27272727272727304,
#  0.08694362017804202,
#  0.08512518409425596,
#  0.061560283687942974,
#  0.04730473047304695]

# %%
df = pd.read_excel('Simulation_Result.xlsx')
version = 13
df = df.loc[df['Ver']==version]#.loc[df['CS']>0]#.loc[df['Exp Raw']>=0]

# %%
ASR_15_P75_fix = df.loc[df['Y']==-1].loc[df['Agg']==15].loc[df['BD']==1]['EXP %'].values.tolist()
ASR_CS_15_P75_fix = df.loc[df['Y']==-1].loc[df['Agg']==15].loc[df['BD']==1]['Residual CS'].values.tolist()
ASR_EM_15_P75_fix = df.loc[df['Y']==-1].loc[df['Agg']==15].loc[df['BD']==1]['Residual EM'].values.tolist()

ASR_30_P75_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==75].loc[df['BD']==1]['EXP %'].values.tolist()
ASR_CS_30_P75_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==75].loc[df['BD']==1]['Residual CS'].values.tolist()
ASR_EM_30_P75_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==75].loc[df['BD']==1]['Residual EM'].values.tolist()

ASR_30_P25_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==25].loc[df['BD']==1]['EXP %'].values.tolist()
ASR_CS_30_P25_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==25].loc[df['BD']==1]['Residual CS'].values.tolist()
ASR_EM_30_P25_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==25].loc[df['BD']==1]['Residual EM'].values.tolist()

ASR_30_P100_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==100].loc[df['BD']==1]['EXP %'].values.tolist()
ASR_CS_30_P100_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==100].loc[df['BD']==1]['Residual CS'].values.tolist()
ASR_EM_30_P100_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==100].loc[df['BD']==1]['Residual EM'].values.tolist()

DEF_exp_30_I100_fix = df.loc[df['Y']==1].loc[df['Agg']==30].loc[df['X']==-1]['EXP %'].values.tolist()
DEF_CS_30_I100_fix = df.loc[df['Y']==1].loc[df['Agg']==30].loc[df['X']==-1]['Residual CS'].values.tolist()
DEF_EM_30_I100_fix = df.loc[df['Y']==1].loc[df['Agg']==30].loc[df['X']==-1]['Residual EM'].values.tolist()

DEF_exp_30_I75_fix = df.loc[df['Y']==1].loc[df['Agg']==30].loc[df['X']==-0.5]['EXP %'].values.tolist()
DEF_CS_30_I75_fix = df.loc[df['Y']==1].loc[df['Agg']==30].loc[df['X']==-0.5]['Residual CS'].values.tolist()
DEF_EM_30_I75_fix = df.loc[df['Y']==1].loc[df['Agg']==30].loc[df['X']==-0.5]['Residual EM'].values.tolist()

DEF_exp_30_I50_fix = df.loc[df['Y']==1].loc[df['Agg']==30].loc[df['X']==0].loc[df['C']==1]['EXP %'].values.tolist()
DEF_CS_30_I50_fix = df.loc[df['Y']==1].loc[df['Agg']==30].loc[df['X']==0].loc[df['C']==1]['Residual CS'].values.tolist()
DEF_EM_30_I50_fix = df.loc[df['Y']==1].loc[df['Agg']==30].loc[df['X']==0].loc[df['C']==1]['Residual EM'].values.tolist()

DEF_exp_15_I50_fix = df.loc[df['Y']==1].loc[df['Agg']==15].loc[df['X']==0]['EXP %'].values.tolist()
DEF_CS_15_I50_fix = df.loc[df['Y']==1].loc[df['Agg']==15].loc[df['X']==0]['Residual CS'].values.tolist()
DEF_EM_15_I50_fix = df.loc[df['Y']==1].loc[df['Agg']==15].loc[df['X']==0]['Residual EM'].values.tolist()

# %%
# ASR Compressive Strength
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4.2,4.2))
#plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental")

plt.plot(ASR_exp_GIANNINI1,ASR_CS_GIANNINI1,'o', color = '#FF00FF',mfc='none',label = "Giannini (2012),\nMixture 1")
plt.plot(ASR_exp_ALKAN,ASR_CS_ALKAN,'o',color = '#D2691E',mfc='none',label = "ALKAN HAFCI\n(2013)")
plt.plot(ASR_exp_TAHMED,ASR_CS_TAHMED,'o',color = '#008080',mfc='none',label = "T.Ahmed et al.\n(2003) Mix B")
plt.plot(ASR_exp_SWAMY,ASR_CS_SWAMY,'o',color = '#800000',mfc='none',label = "Swamy & Al-Asali\n(1988)")

plt.plot(0,0,'wo',label = "      ")

plt.plot(ASR_30_P100_fix,ASR_CS_30_P100_fix,'c-')
plt.plot(ASR_30_P100_fix,ASR_CS_30_P100_fix,'co',label = 'Simulation Result\nASRA30P100')

plt.plot(ASR_30_P75_fix,ASR_CS_30_P75_fix,'b-')
plt.plot(ASR_30_P75_fix,ASR_CS_30_P75_fix,'bo',label = 'Simulation Result\nASRA30P75')

plt.plot(ASR_30_P25_fix,ASR_CS_30_P25_fix,'g-')
plt.plot(ASR_30_P25_fix,ASR_CS_30_P25_fix,'go',label = 'Simulation Result\nASRA30P25')

#plt.plot(ASR_15_P75_fix,ASR_CS_15_P75_fix,'r-')
#plt.plot(ASR_15_P75_fix,ASR_CS_15_P75_fix,'ro',label = 'Simulation Result\nASEA15P75')

##################### GRAPH SETTING #####################
plt.xlim(-0.1,1.5)
plt.ylim(-0.1,1.1)
plt.xlabel('Expansion [%]',fontsize='large')
plt.ylabel('Compressive Strength',fontsize='large')
plt.title( 'ASR Compressive Strength vs. Expansion',fontsize = 'large')
plt.legend(ncol = 1, loc=(1.02,0))
plt.tight_layout()
plt.savefig('ASR CS',dpi = 1000)
plt.show()

# %%
# DEF Compressive Strength

####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4.2,4.2))


plt.plot(DEF_exp_GIANNINI1,DEF_CS_GIANNINI1,'^', color = '#FF00FF',mfc='none',label = "Giannini (2012),\nMixture 1")
plt.plot(DEF_exp_GIANNINI2,DEF_CS_GIANNINI2,'^', color = '#800000',mfc='none',label = "Giannini (2012),\nMixture 2")
plt.plot(DEF_exp_BRUNETAUD,DEF_CS_BRUNETAUD,'^',color = '#D2691E',mfc='none',label = "Brunetaud et al.\n(2008)")

plt.plot(0,0,'wo',label = "      ")

plt.plot(DEF_exp_30_I100_fix,DEF_CS_30_I100_fix,color = '#000080')
plt.plot(DEF_exp_30_I100_fix,DEF_CS_30_I100_fix,'^',color = '#000080',label = 'Simulation Result\nDEFA30I100')

plt.plot(DEF_exp_30_I75_fix,DEF_CS_30_I75_fix,'-', color = '#0000ff')
plt.plot(DEF_exp_30_I75_fix,DEF_CS_30_I75_fix,'^', color = '#0000ff',label = 'Simulation Result\nDEFA30I75')

plt.plot(DEF_exp_30_I50_fix,DEF_CS_30_I50_fix,'-', color = '#00ffff')
plt.plot(DEF_exp_30_I50_fix,DEF_CS_30_I50_fix,'^', color = '#00ffff',label = 'Simulation Result\nDEFA30I50')

#plt.plot(DEF_exp_15_I50_fix,DEF_CS_15_I50_fix,'-',color = '#33cc00')
#plt.plot(DEF_exp_15_I50_fix,DEF_CS_15_I50_fix,'^', color = '#33cc00',label = 'Simulation Result\nDEFA15I50')


##################### GRAPH SETTING #####################
plt.xlim(-0.1,1.5)
plt.ylim(-0.1,1.1)
plt.xlabel('Expansion [%]',fontsize='large')
plt.ylabel('Compressive Strength',fontsize='large')
plt.title( 'DEF Compressive Strength vs. Expansion',fontsize = 'large')
plt.legend(ncol = 1, loc=(1.02,0))
plt.tight_layout()
plt.savefig('DEF',dpi = 1000)
plt.show()

# %%
# ASR Elastic Modulus
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4.2,4.2))
#plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental")

plt.plot(ASR_exp_GIANNINI1,ASR_EM_GIANNINI1,'o', color = '#FF00FF',mfc='none',label = "Giannini (2012),\nMixture 1")
plt.plot(ASR_exp_TAHMED,ASR_EM_TAHMED,'o',color = '#008080',mfc='none',label = "T.Ahmed et al.\n(2003) Mix B")
plt.plot(ASR_exp_SWAMY,ASR_EM_SWAMY,'o',color = '#800000',mfc='none',label = "Swamy & Al-Asali\n(1988)")
plt.plot(0,0,'wo',label = "      ")

plt.plot(ASR_30_P100_fix,ASR_EM_30_P100_fix,'-',color = '#ff0000')
plt.plot(ASR_30_P100_fix,ASR_EM_30_P100_fix,'o',color = '#ff0000',label = 'Simulation Result\nASRA30P100')

plt.plot(ASR_30_P75_fix,ASR_EM_30_P75_fix,'-', color = '#cc33ff')
plt.plot(ASR_30_P75_fix,ASR_EM_30_P75_fix,'o', color = '#cc33ff',label = 'Simulation Result\nASRA30P75')

plt.plot(ASR_30_P25_fix,ASR_EM_30_P25_fix,'-',color = '#ff00bf')
plt.plot(ASR_30_P25_fix,ASR_EM_30_P25_fix,'o',color = '#ff00bf',label = 'Simulation Result\nASRA30P25')

#plt.plot(ASR_15_P75_fix,ASR_EM_15_P75_fix,'-', color = '#ffbf00')
#plt.plot(ASR_15_P75_fix,ASR_EM_15_P75_fix,'o', color = '#ffbf00',label = 'Simulation Result\nASEA15P75')

##################### GRAPH SETTING #####################
plt.xlim(-0.1,1.5)
plt.ylim(-0.1,1.1)
plt.xlabel('Expansion [%]',fontsize='large')
plt.ylabel('Compressive Strength',fontsize='large')
plt.title( 'ASR Elastic Modulus vs. Expansion',fontsize = 'large')
plt.legend(ncol = 1, loc=(1.02,0))
plt.tight_layout()
plt.savefig('ASR EM',dpi = 1000)
plt.show()

# %%
# DEF Elastic Modulus
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4.2,4.2))
#plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental")

plt.plot(DEF_exp_GIANNINI1,DEF_EM_GIANNINI1,'^', color = '#FF00FF',mfc='none',label = "Giannini (2012),\nMixture 1")
plt.plot(DEF_exp_GIANNINI2,DEF_EM_GIANNINI2,'^', color = '#800000',mfc='none',label = "Giannini (2012),\nMixture 2")
plt.plot(DEF_exp_BOUZABATA,DEF_EM_BOUZABATA,'^',color = '#D2691E',mfc='none',label = "Bouzabata et al.\n(2012)")
plt.plot(0,0,'wo',label = "      ")

plt.plot(DEF_exp_30_I100_fix,DEF_EM_30_I100_fix,color = '#000080')
plt.plot(DEF_exp_30_I100_fix,DEF_EM_30_I100_fix,'^',color = '#000080',label = 'Simulation Result\nDEFA30I100')

plt.plot(DEF_exp_30_I75_fix,DEF_EM_30_I75_fix,'-', color = '#0000ff')
plt.plot(DEF_exp_30_I75_fix,DEF_EM_30_I75_fix,'^', color = '#0000ff',label = 'Simulation Result\nDEFA30I75')

plt.plot(DEF_exp_30_I50_fix,DEF_EM_30_I50_fix,'-', color = '#00ffff')
plt.plot(DEF_exp_30_I50_fix,DEF_EM_30_I50_fix,'^', color = '#00ffff',label = 'Simulation Result\nDEFA30I50')

#plt.plot(DEF_exp_15_I50_fix,DEF_EM_15_I50_fix,'-',color = '#33cc00')
#plt.plot(DEF_exp_15_I50_fix,DEF_EM_15_I50_fix,'^', color = '#33cc00',label = 'Simulation Result\nDEFA15I50')

##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.5)
plt.ylim(-0.1,1.2)
plt.xlabel('Expansion [%]',fontsize='large')
plt.ylabel('Elastic Modulus',fontsize='large')
plt.title( 'DEF Elastic Modulus vs. Expansion',fontsize = 'large')
plt.legend(ncol = 1, loc=(1.02,0))
plt.tight_layout()
plt.autoscale()
plt.savefig('DEF EM',dpi = 1000)
plt.show()

# %%
#ff0000
#cc33ff
#ff00bf
#ffbf00


#000080
#0000ff
#00ffff
#33cc00
