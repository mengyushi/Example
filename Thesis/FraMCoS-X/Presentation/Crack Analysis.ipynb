# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
def type():
    if Y == -1:
        return 'ASR'
    elif Y == 1:
        return 'DEF'
    else:
        return 'ASR+DEF'
    
df = pd.read_excel('Simulation_Result.xlsx')

version = 13
df = df.loc[df['Ver']==version].loc[df['CS']>0].loc[df['Exp Raw']>=0]

# %%
df = df.loc[df['SUM OF CRACK']>=0].loc[df['Agg']==30].loc[df['BD']==1]

# %%
df
# Out:
#      Ver   Agg   Per   BD BD-MARK Type    X    Y    C       D  \
# 36  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 37  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 38  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 39  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 40  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 41  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 43  13.0  30.0  25.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 44  13.0  30.0  25.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 45  13.0  30.0  25.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 46  13.0  30.0  25.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 47  13.0  30.0  25.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 49  13.0  30.0   NaN  1.0     FIX  DEF -1.0  1.0  1.0  0.0000
# 50  13.0  30.0   NaN  1.0     FIX  DEF -1.0  1.0  1.0  0.0001
# 51  13.0  30.0   NaN  1.0     FIX  DEF -1.0  1.0  1.0  0.0002
# ...

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 'SUM OF CRACK', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 'SUM OF CRACK', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 'SUM OF CRACK', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 'SUM OF CRACK', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 'SUM OF CRACK', y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 'SUM OF CRACK', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100 C")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 'SUM OF CRACK', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 'SUM OF CRACK', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75 C")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 'SUM OF CRACK', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 'SUM OF CRACK', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50 C")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = 'SUM OF CRACK', y = 'Residual CS',color = '#c4f503',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = 'SUM OF CRACK', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 I50 D")

plt.title("Residual Compressive Strength vs. Total Number of Cracks",fontsize = 'large')
plt.savefig("Residual_Compressive_Strength_vs_Total_Number_of_Cracks", dpi=500)
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = '0-0.00005', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = '0-0.00005', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = '0-0.00005', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = '0-0.00005', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = '0-0.00005', y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = '0-0.00005', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = '0-0.00005', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = '0-0.00005', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = '0-0.00005', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = '0-0.00005', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50")

#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = '0-0.00005', y = 'Residual CS',color = '#c4f503',ax = ax)
#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = '0-0.00005', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Residual Compressive Strength vs. Total Number of Cracks",fontsize = 'large')
plt.savefig("1", dpi=500)
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = '0.00005-0.0001', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = '0.00005-0.0001', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = '0.00005-0.0001', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = '0.00005-0.0001', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = '0.00005-0.0001', y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = '0.00005-0.0001', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = '0.00005-0.0001', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = '0.00005-0.0001', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = '0.00005-0.0001', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = '0.00005-0.0001', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50")

#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = '0.00005-0.0001', y = 'Residual CS',color = '#c4f503',ax = ax)
#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = '0.00005-0.0001', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Residual Compressive Strength vs. 0.0005+mm Cracks",fontsize = 'large')
plt.savefig("2", dpi=500)
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = '0.0001-0.0002', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = '0.0001-0.0002', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = '0.0001-0.0002', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = '0.0001-0.0002', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = '0.0001-0.0002', y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = '0.0001-0.0002', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = '0.0001-0.0002', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = '0.0001-0.0002', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = '0.0001-0.0002', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = '0.0001-0.0002', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50")

#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = '0.0001-0.0002', y = 'Residual CS',color = '#c4f503',ax = ax)
#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = '0.0001-0.0002', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Residual Compressive Strength vs. 0.001+mm Cracks",fontsize = 'large')
plt.savefig("3", dpi=500)
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = '0.0002-0.0005', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = '0.0002-0.0005', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = '0.0002-0.0005', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = '0.0002-0.0005', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = '0.0002-0.0005', y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = '0.0002-0.0005', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = '0.0002-0.0005', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = '0.0002-0.0005', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = '0.0002-0.0005', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = '0.0002-0.0005', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50")

#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = '0.0002-0.0005', y = 'Residual CS',color = '#c4f503',ax = ax)
#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = '0.0002-0.0005', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Residual Compressive Strength vs. 0.002+mm Cracks",fontsize = 'large')
plt.savefig("4", dpi=500)
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = '0.0005-0.001', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = '0.0005-0.001', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75 Case 1")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = '0.0005-0.001', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = '0.0005-0.001', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25 Case 2")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = '0.0005-0.001', y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = '0.0005-0.001', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 X-1 C Case 1")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = '0.0005-0.001', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = '0.0005-0.001', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 X-0.5 C Case 2")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = '0.0005-0.001', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = '0.0005-0.001', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 X0 C Case 3")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = '0.0005-0.001', y = 'Residual CS',color = '#c4f503',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = '0.0005-0.001', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Residual Compressive Strength vs. 0.005+mm Cracks",fontsize = 'large')
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = '0.001-0.003', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = '0.001-0.003', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75 Case 1")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = '0.001-0.003', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = '0.001-0.003', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25 Case 2")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = '0.001-0.003', y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = '0.001-0.003', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 X-1 C Case 1")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = '0.001-0.003', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = '0.001-0.003', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 X-0.5 C Case 2")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = '0.001-0.003', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = '0.001-0.003', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 X0 C Case 3")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = '0.001-0.003', y = 'Residual CS',color = '#c4f503',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = '0.001-0.003', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Residual Compressive Strength vs. 0.01+mm Cracks",fontsize = 'large')
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = '0.003-0.01', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = '0.003-0.01', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75 Case 1")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = '0.003-0.01', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = '0.003-0.01', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25 Case 2")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = '0.003-0.01', y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = '0.003-0.01', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 X-1 C Case 1")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = '0.003-0.01', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = '0.003-0.01', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 X-0.5 C Case 2")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = '0.003-0.01', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = '0.003-0.01', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 X0 C Case 3")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = '0.003-0.01', y = 'Residual CS',color = '#c4f503',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = '0.003-0.01', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Residual Compressive Strength vs. 0.03+mm Cracks",fontsize = 'large')
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = '0.01-0.03', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = '0.01-0.03', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75 Case 1")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = '0.01-0.03', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = '0.01-0.03', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25 Case 2")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = '0.01-0.03', y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = '0.01-0.03', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 X-1 C Case 1")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = '0.01-0.03', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = '0.01-0.03', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 X-0.5 C Case 2")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = '0.01-0.03', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = '0.01-0.03', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 X0 C Case 3")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = '0.01-0.03', y = 'Residual CS',color = '#c4f503',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = '0.01-0.03', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Residual Compressive Strength vs. 0.1+mm Cracks",fontsize = 'large')
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = '0.0005+', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = '0.0005+', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = '0.0005+', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = '0.0005+', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = '0.0005+', y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = '0.0005+', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100 C")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = '0.0005+', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = '0.0005+', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75 C")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = '0.0005+', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = '0.0005+', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50 C")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = '0.0005+', y = 'Residual CS',color = '#c4f503',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = '0.0005+', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 I50 D")

plt.title("Residual Compressive Strength vs. Total Number of 0.0005+mm Cracks",fontsize = 'large')
plt.savefig("Residual_Compressive_Strength_vs_Total_Number_of_0005_Cracks", dpi=500)
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = '0.001+', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = '0.001+', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = '0.001+', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = '0.001+', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = '0.001+', y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = '0.001+', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100 ")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = '0.001+', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = '0.001+', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75 ")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = '0.001+', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = '0.001+', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50 ")

#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = '0.001+', y = 'Residual CS',color = '#c4f503',ax = ax)
#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = '0.001+', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 I50 D")

plt.title("Residual Compressive Strength vs. 0.01+mm Cracks",fontsize = 'large')
#plt.xlim("Cracked Interfaces Larger than 0.01mm")
plt.savefig("Residual_Compressive_Strength_vs_Total_Number_of_001_Cracks", dpi=500)
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 'Cal Crack', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 'Cal Crack', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75 Case 1")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 'Cal Crack', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 'Cal Crack', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25 Case 2")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 'Cal Crack', y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 'Cal Crack', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 X-1 C Case 1")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 'Cal Crack', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 'Cal Crack', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 X-0.5 C Case 2")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 'Cal Crack', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 'Cal Crack', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 X0 C Case 3")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = 'Cal Crack', y = 'Residual CS',color = '#c4f503',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = 'Cal Crack', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Residual Compressive Strength vs. Cal Crackmm Cracks",fontsize = 'large')
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 'Cal Crack', y = 'EXP %',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 'Cal Crack', y = 'EXP %',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 'Cal Crack', y = 'EXP %',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 'Cal Crack', y = 'EXP %',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 'Cal Crack', y = 'EXP %',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 'Cal Crack', y = 'EXP %',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 'Cal Crack', y = 'EXP %',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 'Cal Crack', y = 'EXP %',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 'Cal Crack', y = 'EXP %',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 'Cal Crack', y = 'EXP %',color = '#2e00ff',ax = ax,label = "DEF A30 I50")

#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = 'Cal Crack', y = 'EXP %',color = '#c4f503',ax = ax)
#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = 'Cal Crack', y = 'EXP %',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Total Expansion vs. Cal Crackmm Cracks",fontsize = 'large')

plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 'EXP %', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 'EXP %', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 'EXP %', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 'EXP %', y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 'EXP %', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 'EXP %', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 'EXP %', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 'EXP %', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 'EXP %', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50")

#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = 'EXP %', y = 'Residual CS',color = '#c4f503',ax = ax)
#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = 'EXP %', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Residual Compressive Strength vs. GLOBAL EXPANSION RATIO",fontsize = 'large')
plt.savefig('EXPvsCS',dpi = 1000)
plt.show()

# %%
plt.figure(figsize=(4,4))
'''ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 'Cal Crack', y = 'EXP %',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 'Cal Crack', y = 'EXP %',color = '#ff0000',ax = ax, label = "ASR A30 P75 Case 1")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 'Cal Crack', y = 'EXP %',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 'Cal Crack', y = 'EXP %',color = '#ff7b00', ax = ax, label = "ASR A30 P25 Case 2")
'''
ax = df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 'Cal Crack', y = 'EXP %',color = '#00ff50')
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 'Cal Crack', y = 'EXP %',color = '#00ff50',ax = ax,label = "DEF A30 X-1 C Case 1")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 'Cal Crack', y = 'EXP %',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 'Cal Crack', y = 'EXP %',color = '#00c3ff',ax = ax,label = "DEF A30 X-0.5 C Case 2")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 'Cal Crack', y = 'EXP %',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 'Cal Crack', y = 'EXP %',color = '#2e00ff',ax = ax,label = "DEF A30 X0 C Case 3")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = 'Cal Crack', y = 'EXP %',color = '#c4f503',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = 'Cal Crack', y = 'EXP %',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Total Expansion vs. Cal Crack",fontsize = 'large')
plt.show()

# %%
plt.figure(figsize=(4,4))
'''ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 'Cal Crack', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 'Cal Crack', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75 Case 1")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 'Cal Crack', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 'Cal Crack', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25 Case 2")
'''
ax = df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 'Cal Crack', y = 'Residual CS',color = '#00ff50')
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 'Cal Crack', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 X-1 C Case 1")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 'Cal Crack', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 'Cal Crack', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 X-0.5 C Case 2")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 'Cal Crack', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 'Cal Crack', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 X0 C Case 3")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = 'Cal Crack', y = 'Residual CS',color = '#c4f503',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = 'Cal Crack', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Residual Compressive Strength vs. Cal Crack",fontsize = 'large')
plt.show()

# %%
plt.figure(figsize=(4,4))
'''ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 'EXP %', y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75 Case 1")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 'EXP %', y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 'EXP %', y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25 Case 2")
'''
ax = df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 'EXP %', y = 'Residual CS',color = '#00ff50')
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 'EXP %', y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 X-1 C Case 1")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 'EXP %', y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 'EXP %', y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 X-0.5 C Case 2")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 'EXP %', y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 'EXP %', y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 X0 C Case 3")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = 'EXP %', y = 'Residual CS',color = '#c4f503',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = 'EXP %', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Residual Compressive Strength vs. EXP %",fontsize = 'large')
plt.show()

# %%
df.plot.bar(['0-0.00005'],stacked=True);
