# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
exp_df = pd.read_excel('Research_Result.xlsx')
exp_ASR_exp = exp_df.loc[exp_df['Type']=='ASR']['Expansion (%)'].tolist()
exp_ASR_CS = exp_df.loc[exp_df['Type']=='ASR']['Compressive Strength Remained'].tolist()
exp_ASR_EM = exp_df.loc[exp_df['Type']=='ASR']['Elastic Modulus Remained'].tolist()
exp_ASR_LABELS = exp_df.loc[exp_df['Type']=='ASR']['Resource'].tolist()

exp_DEF_exp = exp_df.loc[exp_df['Type']=='DEF']['Expansion (%)'].tolist()
exp_DEF_CS = exp_df.loc[exp_df['Type']=='DEF']['Compressive Strength Remained'].tolist()
exp_DEF_EM = exp_df.loc[exp_df['Type']=='DEF']['Elastic Modulus Remained'].tolist()
exp_DEF_LABELS = exp_df.loc[exp_df['Type']=='DEF']['Resource'].tolist()
exp_df.head()
# Out:
#                       Resource Type  Expansion (%)  Control Expansion(%)  \
# 0  Giannini (2012), Mixture 1*  DEF          0.000                   0.0
# 1  Giannini (2012), Mixture 1*  DEF          0.102                   0.0
# 2  Giannini (2012), Mixture 1*  DEF          0.208                   0.0
# 3  Giannini (2012), Mixture 1*  DEF          0.344                   0.0
# 4  Giannini (2012), Mixture 1*  DEF          0.415                   0.0
#
#    Damaged Compressive Strength  Control Compressive Strength  \
# 0                     27.366667                     27.366667
# 1                     28.400000                     27.366667
# 2                     26.200000                     27.366667
# 3                     19.666667                     27.366667
# 4                     18.766667                     27.366667
#
#    Compressive Strength Loss  Compressive Strength Remained  \
# 0                   0.000000                       1.000000
# ...

# %%
df = pd.read_excel('Simulation_Result.xlsx')

# %%
version = 13
df = df.loc[df['Ver']==version].loc[df['CS']>0].loc[df['Exp Raw']>=0]
df
# Out:
#      Ver   Agg   Per   BD BD-MARK Type    X    Y    C       D  \
# 18  13.0  15.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 19  13.0  15.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 20  13.0  15.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 21  13.0  15.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 22  13.0  15.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 24  13.0  15.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 26  13.0  15.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 27  13.0  15.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 28  13.0  15.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 30  13.0  30.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 32  13.0  30.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 33  13.0  30.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 34  13.0  30.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 36  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# ...

# %%
ASR_15_75_fix = df.loc[df['Y']==-1].loc[df['Agg']==15].loc[df['BD']==1]['EXP %'].values.tolist()
ASR_CS_15_75_fix = df.loc[df['Y']==-1].loc[df['Agg']==15].loc[df['BD']==1]['Residual CS'].values.tolist()
ASR_EM_15_75_fix = df.loc[df['Y']==-1].loc[df['Agg']==15].loc[df['BD']==1]['Residual EM'].values.tolist()

ASR_15_75_free = df.loc[df['Y']==-1].loc[df['Agg']==15].loc[df['BD']==0]['EXP %'].values.tolist()
ASR_CS_15_75_free = df.loc[df['Y']==-1].loc[df['Agg']==15].loc[df['BD']==0]['Residual CS'].values.tolist()
ASR_EM_15_75_free = df.loc[df['Y']==-1].loc[df['Agg']==15].loc[df['BD']==0]['Residual EM'].values.tolist()

ASR_30_75_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==75].loc[df['BD']==1]['EXP %'].values.tolist()
ASR_CS_30_75_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==75].loc[df['BD']==1]['Residual CS'].values.tolist()
ASR_EM_30_75_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==75].loc[df['BD']==1]['Residual EM'].values.tolist()

ASR_30_25_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==25].loc[df['BD']==1]['EXP %'].values.tolist()
ASR_CS_30_25_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==25].loc[df['BD']==1]['Residual CS'].values.tolist()
ASR_EM_30_25_fix = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['Per']==25].loc[df['BD']==1]['Residual EM'].values.tolist()

ASR_30_75_free = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['BD']==0]['EXP %'].values.tolist()
ASR_CS_30_75_free = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['BD']==0]['Residual CS'].values.tolist()
ASR_EM_30_75_free = df.loc[df['Y']==-1].loc[df['Agg']==30].loc[df['BD']==0]['Residual EM'].values.tolist()

# %%
# Aggregate Percentage vs. ASR
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental")


#plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'0.9')
#plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'ro',label = 'A15% P75 Fix')

plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'0.9')
plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'bo',label = 'A30 P75 Fix')

#plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'0.9')
#plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'bo',mfc='none',label = 'A30% P25 Fix')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.5)
plt.ylim(0,1.2)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL CS',fontsize='large')
plt.title(  'Residual Strength vs. Expansion' ,fontsize = 'large')
plt.legend(fontsize = 'small',loc = 4)
plt.tight_layout()
plt.savefig('ASRCS1',dpi = 1000)
plt.show()

# %%
# Aggregate Percentage vs. ASR
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental")


plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'0.9')
plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'ro',label = 'A15 P75 Fix')

plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'0.9')
plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'bo',label = 'A30 P75 Fix')

#plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'0.9')
#plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'bo',mfc='none',label = 'A30% P25 Fix')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.5)
plt.ylim(0,1.2)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL CS',fontsize='large')
plt.title(  'Residual Strength vs. Expansion' ,fontsize = 'large')
plt.legend(fontsize = 'small',loc = 4)
plt.tight_layout()
plt.savefig('ASRCS2',dpi = 1000)
plt.show()

# %%
# Aggregate Percentage vs. ASR
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental")


#plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'0.9')
#plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'ro',label = 'A15 P75 Fix')

plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'0.9')
plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'bo',label = 'A30 P75 Fix')

plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'0.9')
plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'bo',mfc='none',label = 'A30 P25 Fix')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.5)
plt.ylim(0,1.2)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL CS',fontsize='large')
plt.title(  'Residual Strength vs. Expansion' ,fontsize = 'large')
plt.legend(fontsize = 'small',loc = 4)
plt.tight_layout()
plt.savefig('ASRCS3',dpi = 1000)
plt.show()

# %%
# Aggregate Percentage vs. ASR
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_ASR_exp,exp_ASR_EM,'ko',mfc='none',label = "Experimental")


#plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'0.9')
#plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'ro',label = 'A15% P75 Fix')

plt.plot(ASR_30_75_fix,ASR_EM_30_75_fix,'0.9')
plt.plot(ASR_30_75_fix,ASR_EM_30_75_fix,'bo',label = 'A30 P75 Fix')

#plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'0.9')
#plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'bo',mfc='none',label = 'A30% P25 Fix')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.5)
plt.ylim(0,1.2)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL EM',fontsize='large')
plt.title(  'Residual Elastic Modulus vs. Expansion' ,fontsize = 'large')
plt.legend(fontsize = 'small',loc = 4)
plt.tight_layout()
plt.savefig('ASREM1',dpi = 1000)
plt.show()

# %%
# Aggregate Percentage vs. ASR
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_ASR_exp,exp_ASR_EM,'ko',mfc='none',label = "Experimental")


plt.plot(ASR_15_75_fix,ASR_EM_15_75_fix,'0.9')
plt.plot(ASR_15_75_fix,ASR_EM_15_75_fix,'ro',label = 'A15 P75 Fix')

plt.plot(ASR_30_75_fix,ASR_EM_30_75_fix,'0.9')
plt.plot(ASR_30_75_fix,ASR_EM_30_75_fix,'bo',label = 'A30 P75 Fix')

#plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'0.9')
#plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'bo',mfc='none',label = 'A30% P25 Fix')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.5)
plt.ylim(0,1.2)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL EM',fontsize='large')
plt.title(  'Residual Elastic Modulus vs. Expansion' ,fontsize = 'large')
plt.legend(fontsize = 'small',loc = 4)
plt.tight_layout()
plt.savefig('ASREM2',dpi = 1000)
plt.show()

# %%
# Aggregate Percentage vs. ASR
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_ASR_exp,exp_ASR_EM,'ko',mfc='none',label = "Experimental")


#plt.plot(ASR_15_75_fix,ASR_EM_15_75_fix,'0.9')
#plt.plot(ASR_15_75_fix,ASR_EM_15_75_fix,'ro',label = 'A15 P75 Fix')

plt.plot(ASR_30_75_fix,ASR_EM_30_75_fix,'0.9')
plt.plot(ASR_30_75_fix,ASR_EM_30_75_fix,'bo',label = 'A30 P75 Fix')

plt.plot(ASR_30_25_fix,ASR_EM_30_25_fix,'0.9')
plt.plot(ASR_30_25_fix,ASR_EM_30_25_fix,'bo',mfc='none',label = 'A30 P25 Fix')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.5)
plt.ylim(0,1.2)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL EM',fontsize='large')
plt.title(  'Residual Elastic Modulus vs. Expansion' ,fontsize = 'large')
plt.legend(fontsize = 'small',loc = 4)
plt.tight_layout()
plt.savefig('ASREM3',dpi = 1000)
plt.show()

# %%
# Aggregate Percentage vs. ASR
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_ASR_exp,exp_ASR_EM,'ko',mfc='none',label = "Experimental")


plt.plot(ASR_15_75_fix,ASR_EM_15_75_fix,'0.9')
plt.plot(ASR_15_75_fix,ASR_EM_15_75_fix,'ro',label = 'A15 P75 Fix')

plt.plot(ASR_30_75_fix,ASR_EM_30_75_fix,'0.9')
plt.plot(ASR_30_75_fix,ASR_EM_30_75_fix,'bo',label = 'A30 P75 Fix')

plt.plot(ASR_30_25_fix,ASR_EM_30_25_fix,'0.9')
plt.plot(ASR_30_25_fix,ASR_EM_30_25_fix,'bo',mfc='none',label = 'A30 P25 Fix')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.5)
plt.ylim(0,1.2)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL EM',fontsize='large')
plt.title(  'Residual Elastic Modulus vs. Expansion' ,fontsize = 'large')
plt.legend(fontsize = 'small',loc = 4)
plt.tight_layout()
plt.savefig('ASREM_all',dpi = 1000)
plt.show()

# %%
# Aggregate Percentage vs. ASR
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental")


plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'0.9')
plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'ro',label = 'A15 P75 Fix')

plt.plot(ASR_30_75_free,ASR_CS_30_75_free,'0.9')
plt.plot(ASR_30_75_free,ASR_CS_30_75_free,'bo',mfc='none',label = 'A30 P75 Free')

plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'0.9')
plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'bo',label = 'A30 P75 Fix')

plt.plot(ASR_15_75_free,ASR_CS_15_75_free,'0.9')
plt.plot(ASR_15_75_free,ASR_CS_15_75_free,'ro',mfc='none',label = 'A15 P75 Free')




##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.5)
plt.ylim(0,1.2)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL CS',fontsize='large')
plt.title(  'Residual Strength vs. Expansion' ,fontsize = 'large')
plt.legend(fontsize = 'small',loc = 4)
plt.tight_layout()
plt.savefig('ASR_free',dpi = 1000)
plt.show()

# %%
# Aggregate Percentage vs. ASR
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental")


plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'0.9')
plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'ro',label = 'A15% P75 Fix')

plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'0.9')
plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'bo',label = 'A30% P75 Fix')

#plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'0.9')
#plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'bo',mfc='none',label = 'A30% P25 Fix')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.5)
plt.ylim(0,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel(plot,fontsize='large')
plt.title('Residual Strength vs. Expansion' ,fontsize = 'large')
plt.legend(fontsize = 'small',loc = 4)
plt.tight_layout()
plt.savefig('ASRA30vsA15_cs',dpi = 1000)
plt.show()

# %%
# Reactive Aggregate Percentage vs.ASR
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental")


#plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'0.9')
#plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'ro',label = 'A15% P75 Fix')

plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'0.9')
plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'bo',label = 'A30% P75 Fix')

plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'0.9')
plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'bo',mfc='none',label = 'A30% P25 Fix')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.5)
plt.ylim(0,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel(plot,fontsize='large')
plt.title( 'Residual Strength vs. Expansion',fontsize = 'large')
plt.legend(fontsize = 'small',loc = 4)
plt.tight_layout()
plt.savefig(type() + ' ' + plot +'3',dpi = 1000)
plt.show()

# %%
# Boundary Condition vs ASR
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental")


plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'0.9')
plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'ro',label = 'A15% P75 Fix')

'''plt.plot(ASR_15_75_free,ASR_CS_15_75_free,'0.9')
plt.plot(ASR_15_75_free,ASR_CS_15_75_free,'ro',mfc='none',label = 'A15% P75 Free')'''

plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'0.9')
plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'bo',label = 'A30% P75 Fix')

'''plt.plot(ASR_30_75_free,ASR_CS_30_75_free,'0.9')
plt.plot(ASR_30_75_free,ASR_CS_30_75_free,'bo',mfc='none',label = 'A30% P75 Free')'''


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.6)
plt.ylim(0,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel(plot,fontsize='large')
plt.title( type() + ' ' + plot ,fontsize = 'large')
plt.legend(fontsize = 'small',loc = 4)
plt.tight_layout()
plt.savefig(type() + ' ' + plot +'4',dpi = 1000)
plt.show()

# %%
# ASR CS FIX
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental")


plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'0.9')
plt.plot(ASR_15_75_fix,ASR_CS_15_75_fix,'ro',label = 'A15% P75 Fix')

plt.plot(ASR_15_75_free,ASR_CS_15_75_free,'0.9')
plt.plot(ASR_15_75_free,ASR_CS_15_75_free,'ro',mfc='none',label = 'A15% P75 Free')

plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'0.9')
plt.plot(ASR_30_75_fix,ASR_CS_30_75_fix,'bo',label = 'A30% P75 Fix')

plt.plot(ASR_30_75_free,ASR_CS_30_75_free,'0.9')
plt.plot(ASR_30_75_free,ASR_CS_30_75_free,'bo',mfc='none',label = 'A30% P75 Free')

plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'0.9')
plt.plot(ASR_30_25_fix,ASR_CS_30_25_fix,'bx',label = 'A30% P25 Fix')



##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.2)
plt.ylim(0.2,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel(plot,fontsize='large')
plt.title( type() + ' ' + plot ,fontsize = 'large')
plt.legend(fontsize = 'small',loc = 1)
plt.tight_layout()
plt.savefig(type() + ' ' + plot +'5',dpi = 1000)
plt.show()

# %%
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_ASR_exp,exp_ASR_EM,'ko',mfc='none',label = "Experimental "+plot)


plt.plot(ASR_15_75_fix,ASR_EM_15_75_fix,'0.9')
plt.plot(ASR_15_75_fix,ASR_EM_15_75_fix,'ro',mfc='none',label = 'Agg 15% Fix Simulation '+plot)

plt.plot(ASR_15_75_free,ASR_EM_15_75_free,'0.9')
plt.plot(ASR_15_75_free,ASR_EM_15_75_free,'ro',label = 'Agg 15% Free Simulation '+plot)

plt.plot(ASR_30_75_fix,ASR_EM_30_75_fix,'0.9')
plt.plot(ASR_30_75_fix,ASR_EM_30_75_fix,'bo',mfc='none',label = 'Agg 30% Fix Simulation '+plot)

plt.plot(ASR_30_25_fix,ASR_EM_30_25_fix,'0.9')
plt.plot(ASR_30_25_fix,ASR_EM_30_25_fix,'bx',label = 'Agg 30% Fix Simulation '+plot)

plt.plot(ASR_30_75_free,ASR_EM_30_75_free,'0.9')
plt.plot(ASR_30_75_free,ASR_EM_30_75_free,'bo',label = 'Agg 30% Free Simulation '+plot)


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.0)
plt.ylim(0,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel(plot,fontsize='large')
plt.title( 'ASR RESIDUAL EM' ,fontsize = 'large')
plt.legend(fontsize = 'small',loc = 1)
plt.tight_layout()
plt.savefig('ASR RESIDUAL EM' +'1',dpi = 1000)
plt.show()

# %%
# DEF
Y = 1

exp_30_1_fix = df.loc[df['Y']==Y].loc[df['Agg']==30].loc[df['X']==-1]['EXP %'].values.tolist()
CS_30_1_fix = df.loc[df['Y']==Y].loc[df['Agg']==30].loc[df['X']==-1]['Residual CS'].values.tolist()
EM_30_1_fix = df.loc[df['Y']==Y].loc[df['Agg']==30].loc[df['X']==-1]['Residual EM'].values.tolist()

exp_30_2_fix = df.loc[df['Y']==Y].loc[df['Agg']==30].loc[df['X']==-0.5]['EXP %'].values.tolist()
CS_30_2_fix = df.loc[df['Y']==Y].loc[df['Agg']==30].loc[df['X']==-0.5]['Residual CS'].values.tolist()
EM_30_2_fix = df.loc[df['Y']==Y].loc[df['Agg']==30].loc[df['X']==-0.5]['Residual EM'].values.tolist()

exp_30_3_fix = df.loc[df['Y']==Y].loc[df['Agg']==30].loc[df['X']==0].loc[df['C']==1]['EXP %'].values.tolist()
CS_30_3_fix = df.loc[df['Y']==Y].loc[df['Agg']==30].loc[df['X']==0].loc[df['C']==1]['Residual CS'].values.tolist()
EM_30_3_fix = df.loc[df['Y']==Y].loc[df['Agg']==30].loc[df['X']==0].loc[df['C']==1]['Residual EM'].values.tolist()

exp_30_4_fix = df.loc[df['Y']==Y].loc[df['Agg']==30].loc[df['X']==0].loc[df['C']==0]['EXP %'].values.tolist()
CS_30_4_fix = df.loc[df['Y']==Y].loc[df['Agg']==30].loc[df['X']==0].loc[df['C']==0]['Residual CS'].values.tolist()
EM_30_4_fix = df.loc[df['Y']==Y].loc[df['Agg']==30].loc[df['X']==0].loc[df['C']==0]['Residual EM'].values.tolist()

exp_15_fix = df.loc[df['Y']==Y].loc[df['Agg']==15].loc[df['X']==0]['EXP %'].values.tolist()
CS_15_fix = df.loc[df['Y']==Y].loc[df['Agg']==15].loc[df['X']==0]['Residual CS'].values.tolist()
EM_15_fix = df.loc[df['Y']==Y].loc[df['Agg']==15].loc[df['X']==0]['Residual EM'].values.tolist()

# %%
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_DEF_exp,exp_DEF_CS,'ko',mfc='none',label = "Experimental ")

#plt.plot(exp_30_1_fix,CS_30_1_fix,'0.9')
#plt.plot(exp_30_1_fix,CS_30_1_fix,'ro',label = 'A30% X-1 C '+plot)

#plt.plot(exp_30_2_fix,CS_30_2_fix,'0.9')
#plt.plot(exp_30_2_fix,CS_30_2_fix,'bo',label = 'A30% X-0.5 C '+plot)

plt.plot(exp_30_3_fix,CS_30_3_fix,'0.9')
plt.plot(exp_30_3_fix,CS_30_3_fix,'go',label = 'A30 I50')

#plt.plot(exp_30_4_fix,CS_30_4_fix,'0.9')
#plt.plot(exp_30_4_fix,CS_30_4_fix,'yo',label = 'A30% X0 D '+plot)

#plt.plot(exp_15_fix,CS_15_fix,'0.9')
#plt.plot(exp_15_fix,CS_15_fix,'go',mfc='none',label = 'A15% X0 C '+plot)


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.1)
plt.ylim(0.2,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL CS',fontsize='large')
plt.title( 'Residual Compressive Strength vs. Expansion'  ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 3)
plt.tight_layout()
plt.savefig('DEFCS1',dpi = 1000)
plt.show()

# %%
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_DEF_exp,exp_DEF_CS,'ko',mfc='none',label = "Experimental ")

#plt.plot(exp_30_1_fix,CS_30_1_fix,'0.9')
#plt.plot(exp_30_1_fix,CS_30_1_fix,'ro',label = 'A30% X-1 C '+plot)

#plt.plot(exp_30_2_fix,CS_30_2_fix,'0.9')
#plt.plot(exp_30_2_fix,CS_30_2_fix,'bo',label = 'A30% X-0.5 C '+plot)

plt.plot(exp_30_3_fix,CS_30_3_fix,'0.9')
plt.plot(exp_30_3_fix,CS_30_3_fix,'go',label = 'A30 I50')

#plt.plot(exp_30_4_fix,CS_30_4_fix,'0.9')
#plt.plot(exp_30_4_fix,CS_30_4_fix,'yo',label = 'A30% X0 D '+plot)

plt.plot(exp_15_fix,CS_15_fix,'0.9')
plt.plot(exp_15_fix,CS_15_fix,'go',mfc='none',label = 'A15 I50')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.1)
plt.ylim(0.2,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL CS',fontsize='large')
plt.title( 'Residual Compressive Strength vs. Expansion'  ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 3)
plt.tight_layout()
plt.savefig('DEFCS2',dpi = 1000)
plt.show()

# %%
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_DEF_exp,exp_DEF_CS,'ko',mfc='none',label = "Experimental ")

plt.plot(exp_30_1_fix,CS_30_1_fix,'0.9')
plt.plot(exp_30_1_fix,CS_30_1_fix,'ro',label = 'A30 I100')

plt.plot(exp_30_2_fix,CS_30_2_fix,'0.9')
plt.plot(exp_30_2_fix,CS_30_2_fix,'bo',label = 'A30 I75')

plt.plot(exp_30_3_fix,CS_30_3_fix,'0.9')
plt.plot(exp_30_3_fix,CS_30_3_fix,'go',label = 'A30 I50')

#plt.plot(exp_30_4_fix,CS_30_4_fix,'0.9')
#plt.plot(exp_30_4_fix,CS_30_4_fix,'yo',label = 'A30 X0 D '+plot)

#plt.plot(exp_15_fix,CS_15_fix,'0.9')
#plt.plot(exp_15_fix,CS_15_fix,'go',mfc='none',label = 'A15 I50')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.1)
plt.ylim(0.2,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL CS',fontsize='large')
plt.title( 'Residual Compressive Strength vs. Expansion'  ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 3)
plt.tight_layout()
plt.savefig('DEFCS3',dpi = 1000)
plt.show()

# %%
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_DEF_exp,exp_DEF_CS,'ko',mfc='none',label = "Experimental ")

plt.plot(exp_30_1_fix,CS_30_1_fix,'0.9')
plt.plot(exp_30_1_fix,CS_30_1_fix,'ro',label = 'A30 I100')

plt.plot(exp_30_2_fix,CS_30_2_fix,'0.9')
plt.plot(exp_30_2_fix,CS_30_2_fix,'bo',label = 'A30 I75')

plt.plot(exp_30_3_fix,CS_30_3_fix,'0.9')
plt.plot(exp_30_3_fix,CS_30_3_fix,'go',label = 'A30 I50')

#plt.plot(exp_30_4_fix,CS_30_4_fix,'0.9')
#plt.plot(exp_30_4_fix,CS_30_4_fix,'yo',label = 'A30 X0 D '+plot)

plt.plot(exp_15_fix,CS_15_fix,'0.9')
plt.plot(exp_15_fix,CS_15_fix,'go',mfc='none',label = 'A15 I50')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.1)
plt.ylim(0.2,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL CS',fontsize='large')
plt.title( 'Residual Compressive Strength vs. Expansion'  ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 3)
plt.tight_layout()
plt.savefig('DEFCS_all',dpi = 1000)
plt.show()

# %%
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_DEF_exp,exp_DEF_EM,'ko',mfc='none',label = "Experimental ")

#plt.plot(exp_30_1_fix,EM_30_1_fix,'0.9')
#plt.plot(exp_30_1_fix,EM_30_1_fix,'ro',label = 'A30 I100')

#plt.plot(exp_30_2_fix,EM_30_2_fix,'0.9')
#plt.plot(exp_30_2_fix,EM_30_2_fix,'bo',label = 'A30 I75')

plt.plot(exp_30_3_fix,EM_30_3_fix,'0.9')
plt.plot(exp_30_3_fix,EM_30_3_fix,'go',label = 'A30 I50')

#plt.plot(exp_30_4_fix,EM_30_4_fix,'0.9')
#plt.plot(exp_30_4_fix,EM_30_4_fix,'yo',label = 'A30 X0 D '+plot)

#plt.plot(exp_15_fix,EM_15_fix,'0.9')
#plt.plot(exp_15_fix,EM_15_fix,'go',mfc='none',label = 'A15 I50')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.1)
plt.ylim(0.0,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL EM',fontsize='large')
plt.title( 'Residual Elastic Modulus vs. Expansion'  ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 1)
plt.tight_layout()
plt.savefig('DEFEM1',dpi = 1000)
plt.show()

# %%
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_DEF_exp,exp_DEF_EM,'ko',mfc='none',label = "Experimental ")

#plt.plot(exp_30_1_fix,EM_30_1_fix,'0.9')
#plt.plot(exp_30_1_fix,EM_30_1_fix,'ro',label = 'A30 I100')

#plt.plot(exp_30_2_fix,EM_30_2_fix,'0.9')
#plt.plot(exp_30_2_fix,EM_30_2_fix,'bo',label = 'A30 I75')

plt.plot(exp_30_3_fix,EM_30_3_fix,'0.9')
plt.plot(exp_30_3_fix,EM_30_3_fix,'go',label = 'A30 I50')

#plt.plot(exp_30_4_fix,EM_30_4_fix,'0.9')
#plt.plot(exp_30_4_fix,EM_30_4_fix,'yo',label = 'A30 X0 D '+plot)

plt.plot(exp_15_fix,EM_15_fix,'0.9')
plt.plot(exp_15_fix,EM_15_fix,'go',mfc='none',label = 'A15 I50')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.1)
plt.ylim(0.0,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL EM',fontsize='large')
plt.title( 'Residual Elastic Modulus vs. Expansion'  ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 1)
plt.tight_layout()
plt.savefig('DEFEM2',dpi = 1000)
plt.show()

# %%
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_DEF_exp,exp_DEF_EM,'ko',mfc='none',label = "Experimental ")

plt.plot(exp_30_1_fix,EM_30_1_fix,'0.9')
plt.plot(exp_30_1_fix,EM_30_1_fix,'ro',label = 'A30 I100')

plt.plot(exp_30_2_fix,EM_30_2_fix,'0.9')
plt.plot(exp_30_2_fix,EM_30_2_fix,'bo',label = 'A30 I75')

plt.plot(exp_30_3_fix,EM_30_3_fix,'0.9')
plt.plot(exp_30_3_fix,EM_30_3_fix,'go',label = 'A30 I50')

#plt.plot(exp_30_4_fix,EM_30_4_fix,'0.9')
#plt.plot(exp_30_4_fix,EM_30_4_fix,'yo',label = 'A30 X0 D '+plot)

#plt.plot(exp_15_fix,EM_15_fix,'0.9')
#plt.plot(exp_15_fix,EM_15_fix,'go',mfc='none',label = 'A15 I50')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.1)
plt.ylim(0.0,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL EM',fontsize='large')
plt.title( 'Residual Elastic Modulus vs. Expansion'  ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 1)
plt.tight_layout()
plt.savefig('DEFEM_3',dpi = 1000)
plt.show()

# %%
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_DEF_exp,exp_DEF_EM,'ko',mfc='none',label = "Experimental ")

plt.plot(exp_30_1_fix,EM_30_1_fix,'0.9')
plt.plot(exp_30_1_fix,EM_30_1_fix,'ro',label = 'A30 I100')

plt.plot(exp_30_2_fix,EM_30_2_fix,'0.9')
plt.plot(exp_30_2_fix,EM_30_2_fix,'bo',label = 'A30 I75')

plt.plot(exp_30_3_fix,EM_30_3_fix,'0.9')
plt.plot(exp_30_3_fix,EM_30_3_fix,'go',label = 'A30 I50')

#plt.plot(exp_30_4_fix,EM_30_4_fix,'0.9')
#plt.plot(exp_30_4_fix,EM_30_4_fix,'yo',label = 'A30 X0 D '+plot)

plt.plot(exp_15_fix,EM_15_fix,'0.9')
plt.plot(exp_15_fix,EM_15_fix,'go',mfc='none',label = 'A15 I50')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.1)
plt.ylim(0.0,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel('RESIDUAL EM',fontsize='large')
plt.title( 'Residual Elastic Modulus vs. Expansion'  ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 1)
plt.tight_layout()
plt.savefig('DEFEM_all',dpi = 1000)
plt.show()

# %%
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_DEF_exp,exp_DEF_CS,'ko',mfc='none',label = "Experimental ")



plt.plot(exp_30_3_fix,CS_30_3_fix,'0.9')
plt.plot(exp_30_3_fix,CS_30_3_fix,'go',label = 'A30% I50 ')



plt.plot(exp_15_fix,CS_15_fix,'0.9')
plt.plot(exp_15_fix,CS_15_fix,'go',mfc='none',label = 'A15% I50 ')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.1)
plt.ylim(0.2,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel(plot,fontsize='large')
plt.title( type() + ' ' + plot ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 3)
plt.tight_layout()
plt.savefig(type() + ' ' + plot+'1',dpi = 1000)
plt.show()

# %%
####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_DEF_exp,exp_DEF_CS,'ko',mfc='none',label = "Experimental")

plt.plot(exp_30_1_fix,CS_30_1_fix,'0.9')
plt.plot(exp_30_1_fix,CS_30_1_fix,'ro',label = 'A30% I100')

plt.plot(exp_30_2_fix,CS_30_2_fix,'0.9')
plt.plot(exp_30_2_fix,CS_30_2_fix,'bo',label = 'A30% I75')

plt.plot(exp_30_3_fix,CS_30_3_fix,'0.9')
plt.plot(exp_30_3_fix,CS_30_3_fix,'go',label = 'A30% I50')

'''plt.plot(exp_15_fix,CS_15_fix,'0.9')
plt.plot(exp_15_fix,CS_15_fix,'go',mfc='none',label = 'A15% I50')'''


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.1)
plt.ylim(0.2,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel(plot,fontsize='large')
plt.title( 'DEF' + ' ' + plot ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 3)
plt.tight_layout()
plt.savefig('DEF' + ' ' + plot+'2',dpi = 1000)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(4,4))
plt.plot(exp_DEF_exp,exp_DEF_EM,'ko',mfc='none',label = "Experimental")

plt.plot(exp_30_1_fix,EM_30_1_fix,'0.9')
plt.plot(exp_30_1_fix,EM_30_1_fix,'ro',label = 'A30% X-1 ')

plt.plot(exp_30_2_fix,EM_30_2_fix,'0.9')
plt.plot(exp_30_2_fix,EM_30_2_fix,'bo',label = 'A30% X-0.5 ')

plt.plot(exp_30_3_fix,EM_30_3_fix,'0.9')
plt.plot(exp_30_3_fix,EM_30_3_fix,'go',label = 'A30% X0 ')

plt.plot(exp_15_fix,EM_15_fix,'0.9')
plt.plot(exp_15_fix,EM_15_fix,'go',mfc='none',label = 'A15% X0 ')


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.1)
plt.ylim(0,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel(plot,fontsize='large')
plt.title( type()+' RESIDUAL EM' ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 1)
plt.tight_layout()
plt.savefig(type() + ' ' + plot,dpi = 1000)
plt.show()

# %%
# ASR PERCENTAGE
Y = 1
plot = 'Residual CS'

exp_15 = df.loc[df['Y']==Y].loc[df['Agg']==15]['EXP %'].values.tolist()
CS_15 = df.loc[df['Y']==Y].loc[df['Agg']==15][plot].values.tolist()

exp_30 = df.loc[df['Y']==Y].loc[df['Agg']==30]['EXP %'].values.tolist()
CS_30 = df.loc[df['Y']==Y].loc[df['Agg']==30][plot].values.tolist()

####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,3))
#plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental "+plot)
plt.plot(exp_15,CS_15,'0.9')
plt.plot(exp_15,CS_15,'ro',label = '15% Agg. '+plot)

plt.plot(exp_30,CS_30,'0.9')
plt.plot(exp_30,CS_30,'bo',label = '30% Agg. '+plot)


##################### GRAPH SETTING #####################
plt.xlim(-0.05,1.0)
plt.ylim(0,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel(plot,fontsize='large')
plt.title( type() + ' ' + plot ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 4)
plt.tight_layout()
plt.savefig(type() + ' ' + plot,dpi = 1000)
plt.show()

# %%
df.loc[df['Y']==Y].loc[df['Agg']==15]['EXP %'].values.tolist()
# Out:
# [0.8045, 0.6415, 0.4775, 0.3199, 0.1476, 0.0668, 0.0]

# %%
# ASR PERCENTAGE
Y = 1
plot = 'Residual EM'

exp_15 = df.loc[df['Y']==Y].loc[df['Agg']==15]['EXP %'].values.tolist()
CS_15 = df.loc[df['Y']==Y].loc[df['Agg']==15][plot].values.tolist()

exp_30 = df.loc[df['Y']==Y].loc[df['Agg']==30]['EXP %'].values.tolist()
CS_30 = df.loc[df['Y']==Y].loc[df['Agg']==30][plot].values.tolist()

####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,3))
#plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental "+plot)
plt.plot(exp_15,CS_15,'0.9')
plt.plot(exp_15,CS_15,'ro',label = '15% Agg. '+plot)

plt.plot(exp_30,CS_30,'0.9')
plt.plot(exp_30,CS_30,'bo',label = '30% Agg. '+plot)


##################### GRAPH SETTING #####################
#plt.xlim(-0.05,1.0)
#plt.ylim(0,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel(plot,fontsize='large')
plt.title( type() + ' ' + plot ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 1)
plt.tight_layout()
plt.savefig(type() + ' ' + plot,dpi = 1000)
plt.show()

# %%
# ASR PERCENTAGE
Y = 1
plot = 'Residual CS'

exp_15 = df.loc[df['Y']==Y].loc[df['Agg']==15]['EXP %'].values.tolist()
CS_15 = df.loc[df['Y']==Y].loc[df['Agg']==15][plot].values.tolist()

exp_30 = df.loc[df['Y']==Y].loc[df['Agg']==30]['EXP %'].values.tolist()
CS_30 = df.loc[df['Y']==Y].loc[df['Agg']==30][plot].values.tolist()

####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,3))
#plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental "+plot)
plt.plot(exp_15,CS_15,'0.9')
plt.plot(exp_15,CS_15,'ro',label = 'ASR Expansion')

plt.plot(exp,CS,'0.9')
plt.plot(exp_DEF,CS_DEF,'bo',label = 'DEF Expansion')


##################### GRAPH SETTING #####################
#plt.xlim(-0.05,1.0)
#plt.ylim(0,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel(plot,fontsize='large')
plt.title( "Residual Compresive Strength" ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 1)
plt.tight_layout()
plt.savefig("COMP",dpi = 1000)
plt.show()

# %%
# ASR PERCENTAGE
Y = 1
plot = 'Residual EM'

exp_15 = df.loc[df['Y']==Y].loc[df['Agg']==15]['EXP %'].values.tolist()
CS_15 = df.loc[df['Y']==Y].loc[df['Agg']==15][plot].values.tolist()

exp_30 = df.loc[df['Y']==Y].loc[df['Agg']==30]['EXP %'].values.tolist()
CS_30 = df.loc[df['Y']==Y].loc[df['Agg']==30][plot].values.tolist()

####################### PLOTTING #######################

fig, ax = plt.subplots(figsize=(4,3))
#plt.plot(exp_ASR_exp,exp_ASR_CS,'ko',mfc='none',label = "Experimental "+plot)
plt.plot(exp_15,CS_15,'0.9')
plt.plot(exp_15,CS_15,'ro',label = 'ASR Expansion')

plt.plot(exp,CS,'0.9')
plt.plot(exp_DEF,EM_DEF,'bo',label = 'DEF Expansion')


##################### GRAPH SETTING #####################
#plt.xlim(-0.05,1.0)
#plt.ylim(0,1.1)
plt.xlabel('EXPANSION',fontsize='large')
plt.ylabel(plot,fontsize='large')
plt.title( "Residual Elastic Modulus" ,fontsize = 'large')
plt.legend(fontsize = 'medium',loc = 1)
plt.tight_layout()
plt.savefig("COMP",dpi = 1000)
plt.show()
