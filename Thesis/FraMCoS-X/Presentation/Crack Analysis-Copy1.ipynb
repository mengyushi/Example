# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
def type():
    if Y == -1:
        return 'ASR'
    elif Y == 1:
        return 'DEF'
    else:
        return 'ASR+DEF'
    
df = pd.read_excel('Simulation_Result.xlsx')

version = 13
df = df.loc[df['Ver']==version].loc[df['CS']>0].loc[df['Exp Raw']>=0]

# %%
df
# Out:
#      Ver   Agg   Per   BD BD-MARK Type    X    Y    C       D  \
# 18  13.0  15.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 19  13.0  15.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 20  13.0  15.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 21  13.0  15.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 22  13.0  15.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 24  13.0  15.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 26  13.0  15.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 27  13.0  15.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 28  13.0  15.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 30  13.0  30.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 32  13.0  30.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 33  13.0  30.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 34  13.0  30.0  75.0  0.0    FREE  ASR  0.0 -1.0  1.0  0.0000
# 36  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# ...

# %%
plt.figure(figsize=(4,4))

ax = df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0,color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0,color = '#ff0000',ax = ax, label = "0+mm")


df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.00005,ax = ax,color = '#ff7b00')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.00005,color = '#ff7b00',ax = ax, label = "0.0005+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.0001,ax = ax,color = '#ffcc66')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.0001,color = '#ffcc66',ax = ax, label = "0.001+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.0002,ax = ax,color = '#ccff33')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.0002,color = '#ccff33',ax = ax, label = "0.0002+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.0005,ax = ax,color = '#009900')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.0005,color = '#009900',ax = ax, label = "0.005+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.001,ax = ax,color = '#00cc99')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.001,color = '#00cc99',ax = ax, label = "0.01+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.003,ax = ax,color = '#0099ff')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.003,color = '#0099ff',ax = ax, label = "0.03+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.01,ax = ax,color = '#6666ff')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.01,color = '#6666ff',ax = ax, label = "0.1+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.03,ax = ax,color = '#ff00ff')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.03,color = '#ff00ff',ax = ax, label = "0.3+mm")


ax.set_xlabel('Expansion [%]')
ax.set_ylabel('Number of Cracked Interfaces')

ax.set_ylim(-100,10)

ax.set_title('Number of Cracked Interfaces vs. Expansion')
plt.tight_layout()
plt.savefig('A30P75CRACK.png', dpi=300)

# %%
plt.figure(figsize=(4,4))

ax = df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = '0-0.00005',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = '0-0.00005',color = '#ff0000',ax = ax, label = "0-0.0005mm")


df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = '0.00005-0.0001',ax = ax,color = '#ff7b00')
df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = '0.00005-0.0001',color = '#ff7b00',ax = ax, label = "0.0005-0.001mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = '0.0001-0.0002',ax = ax,color = '#ffcc66')
df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = '0.0001-0.0002',color = '#ffcc66',ax = ax, label = "0.001-0.002mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = '0.0002-0.0005',ax = ax,color = '#ccff33')
df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = '0.0002-0.0005',color = '#ccff33',ax = ax, label = "0.0002-0.0005mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = '0.0005-0.001',ax = ax,color = '#009900')
df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = '0.0005-0.001',color = '#009900',ax = ax, label = "0.005-0.01mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = '0.001-0.003',ax = ax,color = '#00cc99')
df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = '0.001-0.003',color = '#00cc99',ax = ax, label = "0.01-0.03mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = '0.003-0.01',ax = ax,color = '#0099ff')
df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = '0.003-0.01',color = '#0099ff',ax = ax, label = "0.03-0.1mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = '0.01-0.03',ax = ax,color = '#6666ff')
df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = '0.01-0.03',color = '#6666ff',ax = ax, label = "0.1-0.3mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = '0.03-0.1',ax = ax,color = '#ff00ff')
df.loc[df['Type']=='ASR'].loc[df['Agg']==15].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = '0.03-0.1',color = '#ff00ff',ax = ax, label = "0.3-1mm")


ax.set_xlabel('Expansion [%]')
ax.set_ylabel('Number of Cracked Interfaces')


ax.set_title('Number of Cracked Interfaces vs. Expansion')
plt.tight_layout()
plt.savefig('A15P75CRACK.png', dpi=300)

# %%
plt.figure(figsize=(4,4))

ax = df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot.scatter(x = 'EXP %', y = '0-0.00005',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot(x = 'EXP %', y = '0-0.00005',color = '#ff0000',ax = ax, label = "0-0.0005mm")


df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot.scatter(x = 'EXP %', y = '0.00005-0.0001',ax = ax,color = '#ff7b00')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot(x = 'EXP %', y = '0.00005-0.0001',color = '#ff7b00',ax = ax, label = "0.0005-0.001mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot.scatter(x = 'EXP %', y = '0.0001-0.0002',ax = ax,color = '#ffcc66')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot(x = 'EXP %', y = '0.0001-0.0002',color = '#ffcc66',ax = ax, label = "0.001-0.002mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot.scatter(x = 'EXP %', y = '0.0002-0.0005',ax = ax,color = '#ccff33')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot(x = 'EXP %', y = '0.0002-0.0005',color = '#ccff33',ax = ax, label = "0.0002-0.0005mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot.scatter(x = 'EXP %', y = '0.0005-0.001',ax = ax,color = '#009900')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot(x = 'EXP %', y = '0.0005-0.001',color = '#009900',ax = ax, label = "0.005-0.01mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot.scatter(x = 'EXP %', y = '0.001-0.003',ax = ax,color = '#00cc99')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot(x = 'EXP %', y = '0.001-0.003',color = '#00cc99',ax = ax, label = "0.01-0.03mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot.scatter(x = 'EXP %', y = '0.003-0.01',ax = ax,color = '#0099ff')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot(x = 'EXP %', y = '0.003-0.01',color = '#0099ff',ax = ax, label = "0.03-0.1mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot.scatter(x = 'EXP %', y = '0.01-0.03',ax = ax,color = '#6666ff')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot(x = 'EXP %', y = '0.01-0.03',color = '#6666ff',ax = ax, label = "0.1-0.3mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot.scatter(x = 'EXP %', y = '0.03-0.1',ax = ax,color = '#ff00ff')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==25].plot(x = 'EXP %', y = '0.03-0.1',color = '#ff00ff',ax = ax, label = "0.3-1mm")


ax.set_xlabel('Expansion [%]')
ax.set_ylabel('Number of Cracked Interfaces')


ax.set_title('Number of Cracked Interfaces vs. Expansion')
plt.tight_layout()
plt.savefig('A30P25CRACK.png', dpi=300)

# %%
plt.figure(figsize=(4,4))

ax = df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = '0-0.00005',color = '#ff0000')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = '0-0.00005',color = '#ff0000',ax = ax, label = "0-0.0005mm")


df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = '0.00005-0.0001',ax = ax,color = '#ff7b00')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = '0.00005-0.0001',color = '#ff7b00',ax = ax, label = "0.0005-0.001mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = '0.0001-0.0002',ax = ax,color = '#ffcc66')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = '0.0001-0.0002',color = '#ffcc66',ax = ax, label = "0.001-0.002mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = '0.0002-0.0005',ax = ax,color = '#ccff33')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = '0.0002-0.0005',color = '#ccff33',ax = ax, label = "0.0002-0.0005mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = '0.0005-0.001',ax = ax,color = '#009900')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = '0.0005-0.001',color = '#009900',ax = ax, label = "0.005-0.01mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = '0.001-0.003',ax = ax,color = '#00cc99')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = '0.001-0.003',color = '#00cc99',ax = ax, label = "0.01-0.03mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = '0.003-0.01',ax = ax,color = '#0099ff')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = '0.003-0.01',color = '#0099ff',ax = ax, label = "0.03-0.1mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = '0.01-0.03',ax = ax,color = '#6666ff')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = '0.01-0.03',color = '#6666ff',ax = ax, label = "0.1-0.3mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = '0.03-0.1',ax = ax,color = '#ff00ff')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = '0.03-0.1',color = '#ff00ff',ax = ax, label = "0.3-1mm")


ax.set_xlabel('Expansion [%]')
ax.set_ylabel('Number of Cracked Interfaces')


ax.set_title('Number of Cracked Interfaces vs. Expansion')
plt.tight_layout()
plt.savefig('A30X0CCRACK.png', dpi=300)

# %%
plt.figure(figsize=(4,4))

ax = df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot.scatter(x = 'EXP %', y = '0-0.00005',color = '#ff0000')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot(x = 'EXP %', y = '0-0.00005',color = '#ff0000',ax = ax, label = "0-0.0005mm")


df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot.scatter(x = 'EXP %', y = '0.00005-0.0001',ax = ax,color = '#ff7b00')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot(x = 'EXP %', y = '0.00005-0.0001',color = '#ff7b00',ax = ax, label = "0.0005-0.001mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot.scatter(x = 'EXP %', y = '0.0001-0.0002',ax = ax,color = '#ffcc66')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot(x = 'EXP %', y = '0.0001-0.0002',color = '#ffcc66',ax = ax, label = "0.001-0.002mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot.scatter(x = 'EXP %', y = '0.0002-0.0005',ax = ax,color = '#ccff33')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot(x = 'EXP %', y = '0.0002-0.0005',color = '#ccff33',ax = ax, label = "0.0002-0.0005mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot.scatter(x = 'EXP %', y = '0.0005-0.001',ax = ax,color = '#009900')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot(x = 'EXP %', y = '0.0005-0.001',color = '#009900',ax = ax, label = "0.005-0.01mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot.scatter(x = 'EXP %', y = '0.001-0.003',ax = ax,color = '#00cc99')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot(x = 'EXP %', y = '0.001-0.003',color = '#00cc99',ax = ax, label = "0.01-0.03mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot.scatter(x = 'EXP %', y = '0.003-0.01',ax = ax,color = '#0099ff')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot(x = 'EXP %', y = '0.003-0.01',color = '#0099ff',ax = ax, label = "0.03-0.1mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot.scatter(x = 'EXP %', y = '0.01-0.03',ax = ax,color = '#6666ff')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot(x = 'EXP %', y = '0.01-0.03',color = '#6666ff',ax = ax, label = "0.1-0.3mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot.scatter(x = 'EXP %', y = '0.03-0.1',ax = ax,color = '#ff00ff')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-0.5].plot(x = 'EXP %', y = '0.03-0.1',color = '#ff00ff',ax = ax, label = "0.3-1mm")





ax.set_xlabel('Expansion [%]')
ax.set_ylabel('Number of Cracked Interfaces')


ax.set_title('Number of Cracked Interfaces vs. Expansion')
plt.tight_layout()
plt.savefig('A30X-5CCRACK.png', dpi=300)

# %%
plt.figure(figsize=(4,4))

ax = df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot.scatter(x = 'EXP %', y = '0-0.00005',color = '#ff0000')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot(x = 'EXP %', y = '0-0.00005',color = '#ff0000',ax = ax, label = "0-0.0005mm")


df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot.scatter(x = 'EXP %', y = '0.00005-0.0001',ax = ax,color = '#ff7b00')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot(x = 'EXP %', y = '0.00005-0.0001',color = '#ff7b00',ax = ax, label = "0.0005-0.001mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot.scatter(x = 'EXP %', y = '0.0001-0.0002',ax = ax,color = '#ffcc66')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot(x = 'EXP %', y = '0.0001-0.0002',color = '#ffcc66',ax = ax, label = "0.001-0.002mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot.scatter(x = 'EXP %', y = '0.0002-0.0005',ax = ax,color = '#ccff33')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot(x = 'EXP %', y = '0.0002-0.0005',color = '#ccff33',ax = ax, label = "0.0002-0.0005mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot.scatter(x = 'EXP %', y = '0.0005-0.001',ax = ax,color = '#009900')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot(x = 'EXP %', y = '0.0005-0.001',color = '#009900',ax = ax, label = "0.005-0.01mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot.scatter(x = 'EXP %', y = '0.001-0.003',ax = ax,color = '#00cc99')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot(x = 'EXP %', y = '0.001-0.003',color = '#00cc99',ax = ax, label = "0.01-0.03mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot.scatter(x = 'EXP %', y = '0.003-0.01',ax = ax,color = '#0099ff')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot(x = 'EXP %', y = '0.003-0.01',color = '#0099ff',ax = ax, label = "0.03-0.1mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot.scatter(x = 'EXP %', y = '0.01-0.03',ax = ax,color = '#6666ff')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot(x = 'EXP %', y = '0.01-0.03',color = '#6666ff',ax = ax, label = "0.1-0.3mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot.scatter(x = 'EXP %', y = '0.03-0.1',ax = ax,color = '#ff00ff')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==-1].plot(x = 'EXP %', y = '0.03-0.1',color = '#ff00ff',ax = ax, label = "0.3-1mm")


ax.set_xlabel('Expansion [%]')
ax.set_ylabel('Number of Cracked Interfaces')


ax.set_title('Number of Cracked Interfaces vs. Expansion')

plt.tight_layout()

plt.savefig('A30X-1CCRACK.png', dpi=300)

# %%
plt.figure(figsize=(8,4))

ax = df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0,color = '#ff0000',figsize=(8, 5))
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0,color = '#ff0000',ax = ax, label = "ASRA30P75 0+mm")


df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.00005,ax = ax,color = '#ff7b00')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.00005,color = '#ff7b00',ax = ax, label = "ASRA30P75 0.0005+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.0001,ax = ax,color = '#ffcc66')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.0001,color = '#ffcc66',ax = ax, label = "ASRA30P75 0.001+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.0002,ax = ax,color = '#ccff33')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.0002,color = '#ccff33',ax = ax, label = "ASRA30P75 0.0002+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.0005,ax = ax,color = '#009900')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.0005,color = '#009900',ax = ax, label = "ASRA30P75 0.005+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.001,ax = ax,color = '#00cc99')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.001,color = '#00cc99',ax = ax, label = "ASRA30P75 0.01+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.003,ax = ax,color = '#0099ff')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.003,color = '#0099ff',ax = ax, label = "ASRA30P75 0.03+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.01,ax = ax,color = '#6666ff')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.01,color = '#6666ff',ax = ax, label = "ASRA30P75 0.1+mm")

df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot.scatter(x = 'EXP %', y = 0.03,ax = ax,color = '#ff00ff')
df.loc[df['Type']=='ASR'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['Per']==75].plot(x = 'EXP %', y = 0.03,color = '#ff00ff',ax = ax, label = "ASRA30P75 0.3+mm")





df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = 0,color = '#ff0000',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = 0,color = '#ff0000',ax = ax,style='--', label = "DEFA30I50 0+mm")


df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = 0.00005,ax = ax,color = '#ff7b00')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = 0.00005,color = '#ff7b00',ax = ax,style='--', label = "DEFA30I50 0.0005+mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = 0.0001,ax = ax,color = '#ffcc66')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = 0.0001,color = '#ffcc66',style='--',ax = ax, label = "DEFA30I50 0.001+mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = 0.0002,ax = ax,color = '#ccff33')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = 0.0002,color = '#ccff33',style='--',ax = ax, label = "DEFA30I50 0.0002+mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = 0.0005,ax = ax,color = '#009900')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = 0.0005,color = '#009900',style='--',ax = ax, label = "DEFA30I50 0.005+mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = 0.001,ax = ax,color = '#00cc99')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = 0.001,color = '#00cc99',style='--',ax = ax, label = "DEFA30I50 0.01+mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = 0.003,ax = ax,color = '#0099ff')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = 0.003,color = '#0099ff',style='--',ax = ax, label = "DEFA30I50 0.03+mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = 0.01,ax = ax,color = '#6666ff')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = 0.01,color = '#6666ff',style='--',ax = ax, label = "DEFA30I50 0.1+mm")

df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot.scatter(x = 'EXP %', y = 0.03,ax = ax,color = '#ff00ff')
df.loc[df['Type']=='DEF'].loc[df['Agg']==30].loc[df['BD']==1].loc[df['C']==1].loc[df['X']==0].plot(x = 'EXP %', y = 0.03,color = '#ff00ff',style='--',ax = ax, label = "DEFA30I50 0.3+mm")



ax.set_xlabel('Expansion [%]')
ax.set_ylabel('Number of Cracked Interfaces')


ax.set_title('Number of Cracked Interfaces vs. Expansion')
plt.tight_layout()
plt.savefig('Compare.png', dpi=300)
