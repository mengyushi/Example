# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
def type():
    if Y == -1:
        return 'ASR'
    elif Y == 1:
        return 'DEF'
    else:
        return 'ASR+DEF'
    
df = pd.read_excel('Simulation_Result.xlsx')

version = 13
df = df.loc[df['Ver']==version].loc[df['CS']>0].loc[df['Exp Raw']>=0]

# %%
df = df.loc[df['SUM OF CRACK']>=0].loc[df['Agg']==30].loc[df['BD']==1]

# %%
df
# Out:
#      Ver   Agg   Per   BD BD-MARK Type    X    Y    C       D  \
# 36  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 37  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 38  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 39  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 40  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 41  13.0  30.0  75.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 43  13.0  30.0  25.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 44  13.0  30.0  25.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 45  13.0  30.0  25.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 46  13.0  30.0  25.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 47  13.0  30.0  25.0  1.0     FIX  ASR  0.0 -1.0  1.0  0.0000
# 49  13.0  30.0   NaN  1.0     FIX  DEF -1.0  1.0  1.0  0.0000
# 50  13.0  30.0   NaN  1.0     FIX  DEF -1.0  1.0  1.0  0.0001
# 51  13.0  30.0   NaN  1.0     FIX  DEF -1.0  1.0  1.0  0.0002
# ...

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 0, y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 0, y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 0, y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 0, y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 0, y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 0, y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 0, y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 0, y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 0, y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 0, y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50")

#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = '0-0.00005', y = 'Residual CS',color = '#c4f503',ax = ax)
#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = '0-0.00005', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")
ax.figure.set_size_inches(4, 4)



ax.set_xlabel("Total Cracked Interfaces",fontsize = 'large')
ax.set_ylabel("Residual Compressive Strength",fontsize = 'large')
#plt.title("Residual Compressive Strength vs. Total Number of Cracks",fontsize = 'large')
plt.tight_layout()
plt.savefig("total", dpi=500)

plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 0.00005, y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 0.00005, y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 0.00005, y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 0.00005, y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 0.00005, y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 0.00005, y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 0.00005, y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 0.00005, y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 0.00005, y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 0.00005, y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50")

#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = '0.00005', y = 'Residual CS',color = '#c4f503',ax = ax)
#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = '0.00005-0.0001', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")

plt.title("Residual Compressive Strength vs. 0.0005+mm Cracks",fontsize = 'large')
plt.savefig("0005", dpi=500)
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 0.0001, y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 0.0001, y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 0.0001, y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 0.0001, y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 0.0001, y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 0.0001, y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 0.0001, y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 0.0001, y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 0.0001, y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 0.0001, y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50")

#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot.scatter(x = '0.0001-0.0002', y = 'Residual CS',color = '#c4f503',ax = ax)
#df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==0].plot(x = '0.0001-0.0002', y = 'Residual CS',color = '#c4f503',ax = ax,label = "DEF A30 X0 D Case 4")
ax.figure.set_size_inches(4, 4)
ax.set_xlabel("Total Cracked Interfaces \n Larger Than 0.001 mm",fontsize = 'large')
ax.set_ylabel("Residual Compressive Strength",fontsize = 'large')
#plt.title("Residual Compressive Strength vs. 0.001+mm Cracks",fontsize = 'large')
plt.tight_layout()
plt.savefig("001", dpi=500)
plt.show()

# %%
plt.figure(figsize=(4,4))



ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 0.0002, y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 0.0002, y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 0.0002, y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 0.0002, y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 0.0002, y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 0.0002, y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 0.0002, y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 0.0002, y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 0.0002, y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 0.0002, y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50")

plt.title("Residual Compressive Strength vs. 0.002+mm Cracks",fontsize = 'large')
plt.savefig("002", dpi=500)
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 0.0005, y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 0.0005, y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 0.0005, y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 0.0005, y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 0.0005, y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 0.0005, y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 0.0005, y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 0.0005, y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 0.0005, y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 0.0005, y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50")

plt.title("Residual Compressive Strength vs. 0.005+mm Cracks",fontsize = 'large')
plt.savefig("005", dpi=500)
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 0.001, y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 0.001, y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 0.001, y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 0.001, y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 0.001, y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 0.001, y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 0.001, y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 0.001, y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 0.001, y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 0.001, y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50")
ax.figure.set_size_inches(4, 4)
ax.set_xlabel("Total Cracked Interfaces \n Larger Than 0.01 mm",fontsize = 'large')
ax.set_ylabel("Residual Compressive Strength",fontsize = 'large')
#plt.title("Residual Compressive Strength vs. 0.01+mm Cracks",fontsize = 'large')
plt.tight_layout()
plt.savefig("01", dpi=500)
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 0.003, y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 0.003, y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 0.003, y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 0.003, y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 0.003, y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 0.003, y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 0.003, y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 0.003, y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 0.003, y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 0.003, y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50")

# %%
plt.figure(figsize=(4,4))
ax = df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot.scatter(x = 0.01, y = 'Residual CS',color = '#ff0000')
df.loc[df['Type']=='ASR'].loc[df['Per']==75].plot(x = 0.01, y = 'Residual CS',color = '#ff0000',ax = ax, label = "ASR A30 P75")

df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot.scatter(x = 0.01, y = 'Residual CS',color = '#ff7b00', ax = ax)
df.loc[df['Type']=='ASR'].loc[df['Per']==25].plot(x = 0.01, y = 'Residual CS',color = '#ff7b00', ax = ax, label = "ASR A30 P25")

df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot.scatter(x = 0.01, y = 'Residual CS',color = '#00ff50',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-1].plot(x = 0.01, y = 'Residual CS',color = '#00ff50',ax = ax,label = "DEF A30 I100")

df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot.scatter(x = 0.01, y = 'Residual CS',color = '#00c3ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==-0.5].plot(x = 0.01, y = 'Residual CS',color = '#00c3ff',ax = ax,label = "DEF A30 I75")

df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot.scatter(x = 0.01, y = 'Residual CS',color = '#2e00ff',ax = ax)
df.loc[df['Type']=='DEF'].loc[df['X']==0].loc[df['C']==1].plot(x = 0.01, y = 'Residual CS',color = '#2e00ff',ax = ax,label = "DEF A30 I50")

plt.title("Residual Compressive Strength vs. 0.1+mm Cracks",fontsize = 'large')
plt.savefig("100", dpi=500)
plt.show()
